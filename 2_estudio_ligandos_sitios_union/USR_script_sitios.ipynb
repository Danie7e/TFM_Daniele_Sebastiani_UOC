# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title Instalar librerías

# !pip install rdkit
# !pip install Biopython
# !pip install pandarallel
# !pip install py3Dmol
# Out:
# Collecting rdkit
#   Downloading rdkit-2024.9.6-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit) (11.2.1)
# Downloading rdkit-2024.9.6-cp311-cp311-manylinux_2_28_x86_64.whl (34.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 22.9 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2024.9.6
# Collecting Biopython
#   Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from Biopython) (2.0.2)
# Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 32.4 MB/s eta 0:00:00
# Installing collected packages: Biopython
# Successfully installed Biopython-1.85
# Collecting pandarallel
#   Downloading pandarallel-1.6.5.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dill>=0.3.1 (from pandarallel)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.11/dist-packages (from pandarallel) (2.2.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from pandarallel) (5.9.5)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1->pandarallel) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1->pandarallel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1->pandarallel) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1->pandarallel) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1->pandarallel) (1.17.0)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 6.0 MB/s eta 0:00:00
# Building wheels for collected packages: pandarallel
#   Building wheel for pandarallel (setup.py) ... done
#   Created wheel for pandarallel: filename=pandarallel-1.6.5-py3-none-any.whl size=16674 sha256=f54582bc9675d52012dc1c71edad79b489332f94cb0436e06056e63c7316305e
#   Stored in directory: /root/.cache/pip/wheels/b9/c6/5a/829298789e94348b81af52ab42c19d49da007306bbcc983827
# Successfully built pandarallel
# Installing collected packages: dill, pandarallel
# Successfully installed dill-0.4.0 pandarallel-1.6.5
# Collecting py3Dmol
#   Downloading py3Dmol-2.4.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Downloading py3Dmol-2.4.2-py2.py3-none-any.whl (7.0 kB)
# Installing collected packages: py3Dmol
# Successfully installed py3Dmol-2.4.2

# %%
#@title Abrir el dataframe

import os
import pandas as pd

input_folder = "/content/drive/MyDrive/TFM/T2/Analisis_dataframe_final"
input_file = os.path.join(input_folder, "df_filtro_binana_final.csv")
df_harm = pd.read_csv(input_file, sep = ',')
print(df_harm.shape[0],df_harm.columns)
# Out:
# 70378 Index(['level_0', 'index', 'PDB_entry_id', 'Classification', 'Organism',
#        'Uniprot_id', 'Ligand_id', 'Ligand_InChi', 'Experimental_method',
#        'Resolution', 'Adding_Classification', 'Affinity', 'Coordenadas',
#        'Ligand_smiles', 'Mol_Weight', 'n_atoms', 'Nombre', 'Classification_y',
#        'Count_general', 'Count_diff'],
#       dtype='object')

# %%
df_harm.head()
# Out:
#    index PDB_entry_id    Classification  \
# 0      0         4GCP  MEMBRANE PROTEIN
# 1      1         4GCX       TRANSFERASE
# 2      2         4GCY         HYDROLASE
# 3      3         4GDE         ISOMERASE
# 4      4         4GDE         ISOMERASE
#
#                                             Organism Uniprot_id Ligand_id  \
# 0                              Escherichia coli K-12     P02931       AIC
# 1  Zymomonas mobilis subsp. mobilis ZM4 = ATCC 31821     P28720       PRF
# 2                         Mycobacterium tuberculosis     P9WNS5       DUP
# 3                              Aspergillus fumigatus     Q4W1X2       FDA
# 4                              Aspergillus fumigatus     Q4W1X2       FDA
#
#                   Ligand_InChi Experimental_method  Resolution  \
# 0  AVKUERGKIZMTKX-NJBDSQKTSA-N   X-RAY DIFFRACTION        1.98
# 1  MEYMBLGOKYDGLZ-UHFFFAOYSA-N   X-RAY DIFFRACTION        1.42
# 2  XZLLMTSKYYYJLH-SHYZEUOFSA-N   X-RAY DIFFRACTION        1.50
# 3  YPZRHBJKEMOYQH-UYBVJOGSSA-N   X-RAY DIFFRACTION        2.20
# 4  YPZRHBJKEMOYQH-UYBVJOGSSA-N   X-RAY DIFFRACTION        2.20
#
#   Adding_Classification  Affinity           Coordenadas  \
# 0            ANTIBIOTIC       NaN  [70.12, 0, 'B', 401]
# 1                   NaN       NaN  [100.0, 0, 'A', 401]
# 2                   NaN       NaN  [60.48, 0, 'A', 201]
# 3                   NaN       NaN   [91.8, 0, 'A', 601]
# 4                   NaN       NaN  [91.61, 0, 'B', 601]
#
#                                        Ligand_smiles  Mol_Weight  n_atoms  \
# 0  CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccccc3)C(=...     349.412     24.0
# 1                         NCc1c[nH]c2N=C(N)NC(=O)c12     179.183     13.0
# 2  O[C@H]1C[C@@H](O[C@@H]1CO[P](O)(=O)N[P](O)(=O)...     467.157     28.0
# 3  Cc1cc2NC3=C(NC(=O)NC3=O)N(C[C@H](O)[C@H](O)[C@...     787.573     53.0
# 4  Cc1cc2NC3=C(NC(=O)NC3=O)N(C[C@H](O)[C@H](O)[C@...     787.573     53.0
#
#            Nombre  Classification_y  Count_general  Count_diff
# 0  4GCP_AIC_B_401  MEMBRANE PROTEIN             11           3
# 1  4GCX_PRF_A_401       TRANSFERASE             15           2
# 2  4GCY_DUP_A_201         HYDROLASE            129           3
# 3  4GDE_FDA_A_601         ISOMERASE            187           7
# 4  4GDE_FDA_B_601         ISOMERASE            187           7

# %%
#@title Expander el Dataframe por la columna "Coordenadas"

import pandas as pd
import ast

df_harm['Coordenadas'] = df_harm['Coordenadas'].apply(ast.literal_eval)

# %%
nombre_instancias = df_harm['Nombre'].tolist()
print(len(nombre_instancias))
# Out:
# 70378

# %% [markdown]
# El script está en ente enlace: https://gist.github.com/anku255/03dc35c5233a3fc59d60fdf62c3cda24

# %%
#@title Función Ultrafast Shape Recognition

import math, os
from tqdm import tqdm

# --------- LECTOR PDB ---------
class Atom:
    def __init__(self, x, y, z):
        self.x = float(x)
        self.y = float(y)
        self.z = float(z)

    def getXCoordinate(self): return self.x
    def getYCoordinate(self): return self.y
    def getZCoordinate(self): return self.z

class Molecule:
    def __init__(self):
        self.atoms = []

    def addAtom(self, atom):
        self.atoms.append(atom)

    def getAtoms(self): return self.atoms
    def getAtom(self, i): return self.atoms[i]

def readPDBLigand(filepath):
    molecule = Molecule()
    with open(filepath, 'r') as f:
        for line in f:
            if line.startswith("HETATM") or line.startswith("ATOM"):
                try:
                    x = float(line[30:38])
                    y = float(line[38:46])
                    z = float(line[46:54])
                    molecule.addAtom(Atom(x, y, z))
                except:
                    continue
    return molecule

# --------- CÓDIGO USR ---------
class Point():
    def __init__(self, x=0, y=0, z=0):
        self.xCoordinate = x
        self.yCoordinate = y
        self.zCoordinate = z

class AtomIndexAndDistance():
    def __init__(self, index, distance):
        self.index = index
        self.distance = distance

class USR():
    def CalculateCentroid(self, aMolecule):
        centroid = Point()
        atoms = aMolecule.getAtoms()
        if not atoms:
            return centroid
        sx, sy, sz = 0.0, 0.0, 0.0
        for atom in atoms:
            sx += atom.getXCoordinate()
            sy += atom.getYCoordinate()
            sz += atom.getZCoordinate()
        n = len(atoms)
        centroid.xCoordinate = sx / n
        centroid.yCoordinate = sy / n
        centroid.zCoordinate = sz / n
        return centroid

    def EuclideanDistanceMeasure(self, aMolecule, point, i):
        atom = aMolecule.getAtom(i)
        dx = atom.getXCoordinate() - point.xCoordinate
        dy = atom.getYCoordinate() - point.yCoordinate
        dz = atom.getZCoordinate() - point.zCoordinate
        return math.sqrt(dx*dx + dy*dy + dz*dz)

    def ClosestAndFurthestAtomToCentroid(self, aMolecule):
        centroid = self.CalculateCentroid(aMolecule)
        distances = []
        for i in range(len(aMolecule.getAtoms())):
            dist = self.EuclideanDistanceMeasure(aMolecule, centroid, i)
            distances.append(AtomIndexAndDistance(i, dist))
        distances.sort(key=lambda x: x.distance)
        return [distances[0], distances[-1]]

    def FurthestAtomFromFurthestAtom(self, aMolecule, furthestAtom):
        index = furthestAtom.index
        target = aMolecule.getAtom(index)
        distances = []
        for i in range(len(aMolecule.getAtoms())):
            atom = aMolecule.getAtom(i)
            dx = atom.getXCoordinate() - target.getXCoordinate()
            dy = atom.getYCoordinate() - target.getYCoordinate()
            dz = atom.getZCoordinate() - target.getZCoordinate()
            dist = math.sqrt(dx*dx + dy*dy + dz*dz)
            distances.append(AtomIndexAndDistance(i, dist))
        distances.sort(key=lambda x: x.distance)
        return distances[-1].index

    def MomentToCentroid(self, momentId, aMolecule, centroid):
        atoms = aMolecule.getAtoms()
        distances = []
        for atom in atoms:
            dx = atom.getXCoordinate() - centroid.xCoordinate
            dy = atom.getYCoordinate() - centroid.yCoordinate
            dz = atom.getZCoordinate() - centroid.zCoordinate
            distances.append(math.sqrt(dx*dx + dy*dy + dz*dz))
        return self._moment(momentId, distances)

    def MomentToX(self, momentId, aMolecule, refIndex):
        ref = aMolecule.getAtom(refIndex)
        distances = []
        for atom in aMolecule.getAtoms():
            dx = atom.getXCoordinate() - ref.getXCoordinate()
            dy = atom.getYCoordinate() - ref.getYCoordinate()
            dz = atom.getZCoordinate() - ref.getZCoordinate()
            distances.append(math.sqrt(dx*dx + dy*dy + dz*dz))
        return self._moment(momentId, distances)

    def _moment(self, momentId, distances):
        n = len(distances)
        mean = sum(distances) / n
        if momentId == 1:
            return mean
        elif momentId == 2:
            return sum((d - mean)**2 for d in distances) / n
        elif momentId == 3:
            variance = sum((d - mean)**2 for d in distances) / n
            skewness = sum(abs(d - mean)**3 for d in distances) / n
            return skewness / (variance ** 1.5) if variance > 0 else 0.0

def getUSRDescriptor(aMolecule):
    usr = USR()
    centroid = usr.CalculateCentroid(aMolecule)
    v = usr.ClosestAndFurthestAtomToCentroid(aMolecule)
    ffaIndex = usr.FurthestAtomFromFurthestAtom(aMolecule, v[1])
    return [
        usr.MomentToCentroid(1, aMolecule, centroid),
        usr.MomentToCentroid(2, aMolecule, centroid),
        usr.MomentToCentroid(3, aMolecule, centroid),
        usr.MomentToX(1, aMolecule, v[0].index),
        usr.MomentToX(2, aMolecule, v[0].index),
        usr.MomentToX(3, aMolecule, v[0].index),
        usr.MomentToX(1, aMolecule, v[1].index),
        usr.MomentToX(2, aMolecule, v[1].index),
        usr.MomentToX(3, aMolecule, v[1].index),
        usr.MomentToX(1, aMolecule, ffaIndex),
        usr.MomentToX(2, aMolecule, ffaIndex),
        usr.MomentToX(3, aMolecule, ffaIndex),
    ]

# %%
#@title Función USR para los sitios agrupados

import os
import glob
from collections import defaultdict
from tqdm import tqdm
import math

#############################
# LECTOR PDB Y DESCRIPTORES #
#############################

# --------- LECTOR PDB ---------
class Atom:
    def __init__(self, x, y, z):
        self.x = float(x)
        self.y = float(y)
        self.z = float(z)

    def getXCoordinate(self):
        return self.x
    def getYCoordinate(self):
        return self.y
    def getZCoordinate(self):
        return self.z

class Molecule:
    def __init__(self):
        self.atoms = []

    def addAtom(self, atom):
        self.atoms.append(atom)

    def getAtoms(self):
        return self.atoms
    def getAtom(self, i):
        return self.atoms[i]

def readPDBLigand(filepath):
    molecule = Molecule()
    with open(filepath, 'r') as f:
        for line in f:
            if line.startswith("HETATM") or line.startswith("ATOM"):
                try:
                    x = float(line[30:38])
                    y = float(line[38:46])
                    z = float(line[46:54])
                    molecule.addAtom(Atom(x, y, z))
                except Exception as ex:
                    # Si ocurre algún error al convertir las coordenadas, se salta la línea.
                    continue
    return molecule

# --------- CÓDIGO USR ---------
class Point:
    def __init__(self, x=0, y=0, z=0):
        self.xCoordinate = x
        self.yCoordinate = y
        self.zCoordinate = z

class AtomIndexAndDistance:
    def __init__(self, index, distance):
        self.index = index
        self.distance = distance

class USR:
    def CalculateCentroid(self, aMolecule):
        centroid = Point()
        atoms = aMolecule.getAtoms()
        if not atoms:
            return centroid
        sx, sy, sz = 0.0, 0.0, 0.0
        for atom in atoms:
            sx += atom.getXCoordinate()
            sy += atom.getYCoordinate()
            sz += atom.getZCoordinate()
        n = len(atoms)
        centroid.xCoordinate = sx / n
        centroid.yCoordinate = sy / n
        centroid.zCoordinate = sz / n
        return centroid

    def EuclideanDistanceMeasure(self, aMolecule, point, i):
        atom = aMolecule.getAtom(i)
        dx = atom.getXCoordinate() - point.xCoordinate
        dy = atom.getYCoordinate() - point.yCoordinate
        dz = atom.getZCoordinate() - point.zCoordinate
        return math.sqrt(dx*dx + dy*dy + dz*dz)

    def ClosestAndFurthestAtomToCentroid(self, aMolecule):
        centroid = self.CalculateCentroid(aMolecule)
        distances = []
        for i in range(len(aMolecule.getAtoms())):
            dist = self.EuclideanDistanceMeasure(aMolecule, centroid, i)
            distances.append(AtomIndexAndDistance(i, dist))
        distances.sort(key=lambda x: x.distance)
        return [distances[0], distances[-1]]

    def FurthestAtomFromFurthestAtom(self, aMolecule, furthestAtom):
        index = furthestAtom.index
        target = aMolecule.getAtom(index)
        distances = []
        for i in range(len(aMolecule.getAtoms())):
            atom = aMolecule.getAtom(i)
            dx = atom.getXCoordinate() - target.getXCoordinate()
            dy = atom.getYCoordinate() - target.getYCoordinate()
            dz = atom.getZCoordinate() - target.getZCoordinate()
            dist = math.sqrt(dx*dx + dy*dy + dz*dz)
            distances.append(AtomIndexAndDistance(i, dist))
        distances.sort(key=lambda x: x.distance)
        return distances[-1].index

    def MomentToCentroid(self, momentId, aMolecule, centroid):
        atoms = aMolecule.getAtoms()
        distances = []
        for atom in atoms:
            dx = atom.getXCoordinate() - centroid.xCoordinate
            dy = atom.getYCoordinate() - centroid.yCoordinate
            dz = atom.getZCoordinate() - centroid.zCoordinate
            distances.append(math.sqrt(dx*dx + dy*dy + dz*dz))
        return self._moment(momentId, distances)

    def MomentToX(self, momentId, aMolecule, refIndex):
        ref = aMolecule.getAtom(refIndex)
        distances = []
        for atom in aMolecule.getAtoms():
            dx = atom.getXCoordinate() - ref.getXCoordinate()
            dy = atom.getYCoordinate() - ref.getYCoordinate()
            dz = atom.getZCoordinate() - ref.getZCoordinate()
            distances.append(math.sqrt(dx*dx + dy*dy + dz*dz))
        return self._moment(momentId, distances)

    def _moment(self, momentId, distances):
        n = len(distances)
        mean = sum(distances) / n
        if momentId == 1:
            return mean
        elif momentId == 2:
            return sum((d - mean)**2 for d in distances) / n
        elif momentId == 3:
            variance = sum((d - mean)**2 for d in distances) / n
            skewness = sum(abs(d - mean)**3 for d in distances) / n
            return skewness / (variance ** 1.5) if variance > 0 else 0.0

def getUSRDescriptor(aMolecule):
    usr = USR()
    centroid = usr.CalculateCentroid(aMolecule)
    v = usr.ClosestAndFurthestAtomToCentroid(aMolecule)
    ffaIndex = usr.FurthestAtomFromFurthestAtom(aMolecule, v[1])
    return [
        usr.MomentToCentroid(1, aMolecule, centroid),
        usr.MomentToCentroid(2, aMolecule, centroid),
        usr.MomentToCentroid(3, aMolecule, centroid),
        usr.MomentToX(1, aMolecule, v[0].index),
        usr.MomentToX(2, aMolecule, v[0].index),
        usr.MomentToX(3, aMolecule, v[0].index),
        usr.MomentToX(1, aMolecule, v[1].index),
        usr.MomentToX(2, aMolecule, v[1].index),
        usr.MomentToX(3, aMolecule, v[1].index),
        usr.MomentToX(1, aMolecule, ffaIndex),
        usr.MomentToX(2, aMolecule, ffaIndex),
        usr.MomentToX(3, aMolecule, ffaIndex),
    ]

# %%
nombre_instancias_sitios = [f"{i}_sitio.pdb" for i in nombre_instancias]

# %%
nombre_instancias_sitios
# Out:
# ['4GCP_AIC_B_401_sitio.pdb',
#  '4GCX_PRF_A_401_sitio.pdb',
#  '4GCY_DUP_A_201_sitio.pdb',
#  '4GDE_FDA_A_601_sitio.pdb',
#  '4GDE_FDA_B_601_sitio.pdb',
#  '4GDE_FDA_C_601_sitio.pdb',
#  '4GDE_FDA_D_601_sitio.pdb',
#  '4GE1_TSS_A_201_sitio.pdb',
#  '4GE1_TSS_B_201_sitio.pdb',
#  '4GE1_TSS_C_201_sitio.pdb',
#  '4GE1_TSS_D_201_sitio.pdb',
#  '4GEO_BOG_A_401_sitio.pdb',
#  '4GEO_BOG_A_402_sitio.pdb',
#  '4GEY_C8E_A_503_sitio.pdb',
#  '4GF9_LP5_C_501_sitio.pdb',
#  '4GF9_STE_B_201_sitio.pdb',
#  '4GG1_TZD_A_601_sitio.pdb',
#  '4GH0_MYS_A_302_sitio.pdb',
#  '4GH8_MTX_B_201_sitio.pdb',
#  '4GH8_MTX_A_201_sitio.pdb',
#  '4GHD_DHY_C_403_sitio.pdb',
#  '4GHD_P6G_A_402_sitio.pdb',
#  '4GHD_P6G_B_403_sitio.pdb',
#  '4GHD_P6G_B_404_sitio.pdb',
#  '4GHD_P6G_C_402_sitio.pdb',
#  '4GHD_P6G_D_402_sitio.pdb',
#  '4GHE_P6G_A_402_sitio.pdb',
#  '4GHE_P6G_B_403_sitio.pdb',
#  '4GHE_P6G_B_404_sitio.pdb',
#  '4GHE_P6G_B_406_sitio.pdb',
#  '4GHE_P6G_C_402_sitio.pdb',
#  '4GHE_P6G_C_404_sitio.pdb',
#  '4GHE_P6G_D_402_sitio.pdb',
#  '4GHE_4NC_C_403_sitio.pdb',
#  '4GHF_4NC_A_402_sitio.pdb',
#  '4GHF_P6G_A_403_sitio.pdb',
#  '4GHF_P6G_B_405_sitio.pdb',
#  '4GHF_P6G_B_406_sitio.pdb',
#  '4GHF_P6G_C_404_sitio.pdb',
#  '4GHF_P6G_D_403_sitio.pdb',
#  '4GHG_P6G_A_402_sitio.pdb',
#  '4GHG_P6G_B_403_sitio.pdb',
#  '4GHG_P6G_B_404_sitio.pdb',
#  '4GHG_P6G_C_402_sitio.pdb',
#  '4GHG_P6G_D_402_sitio.pdb',
#  '4GHG_DHY_C_403_sitio.pdb',
#  '4GHH_P6G_A_402_sitio.pdb',
#  '4GHH_P6G_B_403_sitio.pdb',
#  '4GHH_P6G_B_404_sitio.pdb',
#  '4GHH_P6G_C_402_sitio.pdb',
#  '4GHH_P6G_D_402_sitio.pdb',
#  '4GHH_4NC_C_403_sitio.pdb',
#  '4GHH_4NC_D_403_sitio.pdb',
#  '4GHI_0X3_A_401_sitio.pdb',
#  '4GHM_PRF_A_301_sitio.pdb',
#  '4GHM_PRF_B_301_sitio.pdb',
#  '4GHW_DKA_A_302_sitio.pdb',
#  '4GHW_DKA_B_302_sitio.pdb',
#  '4GI6_GLC_A_602_sitio.pdb',
#  '4GIS_MLA_A_403_sitio.pdb',
#  '4GIS_MAE_B_404_sitio.pdb',
#  '4GIU_PRP_A_401_sitio.pdb',
#  '4GIU_PRP_B_401_sitio.pdb',
#  '4GJI_RNS_A_1001_sitio.pdb',
#  '4GJI_RNS_B_502_sitio.pdb',
#  '4GJI_RNS_C_501_sitio.pdb',
#  '4GJI_RNS_D_502_sitio.pdb',
#  '4GJI_RAM_A_1002_sitio.pdb',
#  '4GJI_RAM_B_503_sitio.pdb',
#  '4GJI_RAM_C_502_sitio.pdb',
#  '4GJI_RAM_D_503_sitio.pdb',
#  '4GJI_RM4_B_501_sitio.pdb',
#  '4GJI_RM4_B_504_sitio.pdb',
#  '4GJI_RM4_D_501_sitio.pdb',
#  '4GJQ_HEX_A_302_sitio.pdb',
#  '4GJY_OGA_A_502_sitio.pdb',
#  '4GJZ_AKG_A_502_sitio.pdb',
#  '4GKM_PRP_A_401_sitio.pdb',
#  '4GKM_PRP_B_401_sitio.pdb',
#  '4GLB_XXH_A_301_sitio.pdb',
#  '4GLB_XXH_B_301_sitio.pdb',
#  '4GLW_NMN_B_403_sitio.pdb',
#  '4GLY_P6G_A_310_sitio.pdb',
#  '4GM0_TZD_A_601_sitio.pdb',
#  '4GM1_TZD_A_606_sitio.pdb',
#  '4GM4_TZD_A_605_sitio.pdb',
#  '4GMD_ATM_A_301_sitio.pdb',
#  '4GMD_ATM_B_301_sitio.pdb',
#  '4GMD_ATM_C_301_sitio.pdb',
#  '4GMD_ATM_D_301_sitio.pdb',
#  '4GME_CS2_C_503_sitio.pdb',
#  '4GN8_ASO_A_304_sitio.pdb',
#  '4GN8_ASO_A_306_sitio.pdb',
#  '4GN8_ASO_A_307_sitio.pdb',
#  '4GN8_ASO_B_313_sitio.pdb',
#  '4GN8_ASO_B_315_sitio.pdb',
#  '4GN8_ASO_B_316_sitio.pdb',
#  '4GN8_ASO_B_317_sitio.pdb',
#  '4GNA_XYL_A_302_sitio.pdb',
#  '4GNA_XYL_B_301_sitio.pdb',
#  '4GNC_ASO_A_302_sitio.pdb',
#  '4GNC_ASO_A_303_sitio.pdb',
#  '4GNC_ASO_B_302_sitio.pdb',
#  '4GNC_ASO_B_303_sitio.pdb',
#  '4GNC_ASO_B_304_sitio.pdb',
#  '4GNL_GDP_A_704_sitio.pdb',
#  '4GNP_GDP_A_701_sitio.pdb',
#  '4GNY_SDS_A_201_sitio.pdb',
#  '4GOJ_GNP_A_201_sitio.pdb',
#  '4GOJ_GNP_B_201_sitio.pdb',
#  '4GOK_GNP_B_201_sitio.pdb',
#  '4GOK_GNP_A_201_sitio.pdb',
#  '4GOM_0Y0_D_301_sitio.pdb',
#  '4GOM_0Y0_E_301_sitio.pdb',
#  '4GOM_0Y0_F_301_sitio.pdb',
#  '4GOV_DTT_A_511_sitio.pdb',
#  '4GOX_A3P_A_401_sitio.pdb',
#  '4GOY_DTT_B_515_sitio.pdb',
#  '4GP0_DTT_A_517_sitio.pdb',
#  '4GP0_DTT_B_531_sitio.pdb',
#  '4GP0_DTT_B_532_sitio.pdb',
#  '4GP1_DMA_A_402_sitio.pdb',
#  '4GP2_DMA_A_403_sitio.pdb',
#  '4GP2_DMA_A_404_sitio.pdb',
#  '4GP2_DMA_B_404_sitio.pdb',
#  '4GP2_DMA_B_405_sitio.pdb',
#  '4GP4_HAS_A_603_sitio.pdb',
#  '4GP4_OLC_A_605_sitio.pdb',
#  '4GP4_OLC_A_606_sitio.pdb',
#  '4GP4_OLC_A_607_sitio.pdb',
#  '4GP4_OLC_A_615_sitio.pdb',
#  '4GP4_OLC_A_617_sitio.pdb',
#  '4GP4_OLC_B_202_sitio.pdb',
#  '4GP4_OLC_B_203_sitio.pdb',
#  '4GP4_OLC_B_204_sitio.pdb',
#  '4GP5_OLC_A_605_sitio.pdb',
#  '4GP5_OLC_A_612_sitio.pdb',
#  '4GP5_OLC_A_614_sitio.pdb',
#  '4GP5_OLC_B_202_sitio.pdb',
#  '4GP5_OLC_B_203_sitio.pdb',
#  '4GP5_OLC_B_204_sitio.pdb',
#  '4GP5_OLC_C_101_sitio.pdb',
#  '4GP5_OLC_C_102_sitio.pdb',
#  '4GP8_OLC_A_605_sitio.pdb',
#  '4GP8_OLC_A_606_sitio.pdb',
#  '4GP8_OLC_A_607_sitio.pdb',
#  '4GP8_OLC_A_615_sitio.pdb',
#  '4GP8_OLC_A_617_sitio.pdb',
#  '4GP8_OLC_B_202_sitio.pdb',
#  '4GP8_OLC_B_203_sitio.pdb',
#  '4GP8_OLC_C_101_sitio.pdb',
#  '4GP8_HAS_A_603_sitio.pdb',
#  '4GP9_TZD_A_602_sitio.pdb',
#  '4GPC_BLA_A_901_sitio.pdb',
#  '4GPC_BLA_B_601_sitio.pdb',
#  '4GPC_BLA_C_901_sitio.pdb',
#  '4GPE_TZD_A_605_sitio.pdb',
#  '4GPF_BLA_A_901_sitio.pdb',
#  '4GPF_BLA_B_606_sitio.pdb',
#  '4GPF_BLA_C_905_sitio.pdb',
#  '4GPH_BLA_B_601_sitio.pdb',
#  '4GQ0_QAP_A_401_sitio.pdb',
#  '4GQC_DTD_C_202_sitio.pdb',
#  '4GQC_DTD_D_201_sitio.pdb',
#  '4GQE_H4B_A_802_sitio.pdb',
#  '4GQE_H4B_B_802_sitio.pdb',
#  '4GQQ_0XR_A_502_sitio.pdb',
#  '4GQQ_0XR_A_503_sitio.pdb',
#  '4GQQ_0XR_A_504_sitio.pdb',
#  '4GQR_MYC_A_504_sitio.pdb',
#  '4GQY_AMP_A_301_sitio.pdb',
#  '4GQY_AMP_B_301_sitio.pdb',
#  '4GQY_AMP_C_301_sitio.pdb',
#  '4GQY_AMP_D_301_sitio.pdb',
#  '4GR5_APC_A_601_sitio.pdb',
#  '4GR5_APC_B_601_sitio.pdb',
#  '4GR5_APC_C_601_sitio.pdb',
#  '4GR5_APC_D_601_sitio.pdb',
#  '4GRA_A3P_A_301_sitio.pdb',
#  '4GRA_A3P_B_301_sitio.pdb',
#  '4GS4_ACO_A_401_sitio.pdb',
#  '4GS9_PE8_A_402_sitio.pdb',
#  '4GSP_SGP_A_106_sitio.pdb',
#  '4GSP_3GP_A_105_sitio.pdb',
#  '4GSS_GTX_A_210_sitio.pdb',
#  '4GSS_GTX_B_210_sitio.pdb',
#  '4GSV_ABH_A_403_sitio.pdb',
#  '4GSV_ABH_B_403_sitio.pdb',
#  '4GSZ_ABH_A_405_sitio.pdb',
#  '4GSZ_ABH_B_403_sitio.pdb',
#  '4GT1_DGI_A_401_sitio.pdb',
#  '4GT9_UMP_A_302_sitio.pdb',
#  '4GTA_UMP_A_302_sitio.pdb',
#  '4GTB_UMP_A_302_sitio.pdb',
#  '4GTD_UMP_A_301_sitio.pdb',
#  '4GTD_UMP_B_301_sitio.pdb',
#  '4GTD_UMP_C_302_sitio.pdb',
#  '4GTD_UMP_D_302_sitio.pdb',
#  '4GTF_UMP_A_302_sitio.pdb',
#  '4GTM_FPP_B_502_sitio.pdb',
#  '4GTP_FPP_B_502_sitio.pdb',
#  '4GTQ_FPP_B_502_sitio.pdb',
#  '4GTR_FPP_B_503_sitio.pdb',
#  '4GU8_DTT_E_301_sitio.pdb',
#  '4GUE_QCT_A_401_sitio.pdb',
#  '4GUI_QIC_A_301_sitio.pdb',
#  '4GUI_QIC_B_301_sitio.pdb',
#  '4GUJ_SKM_A_301_sitio.pdb',
#  '4GUJ_SKM_B_303_sitio.pdb',
#  '4GV7_MEW_A_1101_sitio.pdb',
#  '4GV7_MEW_B_1101_sitio.pdb',
#  '4GV7_MEW_C_1101_sitio.pdb',
#  '4GV7_MEW_D_1101_sitio.pdb',
#  '4GV8_DUP_A_201_sitio.pdb',
#  '4GV8_DUP_B_201_sitio.pdb',
#  '4GV8_DUP_C_201_sitio.pdb',
#  '4GV8_DUP_D_201_sitio.pdb',
#  '4GV8_DUP_E_201_sitio.pdb',
#  '4GV8_DUP_F_201_sitio.pdb',
#  '4GVF_NDG_A_401_sitio.pdb',
#  '4GVF_NDG_B_401_sitio.pdb',
#  '4GVI_AH0_A_402_sitio.pdb',
#  '4GVI_AH0_B_401_sitio.pdb',
#  '4GVL_AMP_A_602_sitio.pdb',
#  '4GVL_AMP_B_602_sitio.pdb',
#  '4GVL_AMP_C_602_sitio.pdb',
#  '4GVL_AMP_D_602_sitio.pdb',
#  '4GVX_FUL_A_303_sitio.pdb',
#  '4GVX_FUL_B_304_sitio.pdb',
#  '4GVX_FUL_C_303_sitio.pdb',
#  '4GVX_FUL_D_303_sitio.pdb',
#  '4GVY_CIR_A_403_sitio.pdb',
#  '4GVZ_DAR_A_404_sitio.pdb',
#  '4GW0_ILO_A_403_sitio.pdb',
#  '4GW2_ORN_A_403_sitio.pdb',
#  '4GWD_ABH_A_404_sitio.pdb',
#  '4GWD_ABH_B_404_sitio.pdb',
#  '4GWK_3PG_A_501_sitio.pdb',
#  '4GWK_3PG_A_504_sitio.pdb',
#  '4GWS_AMP_A_403_sitio.pdb',
#  '4GWS_AMP_B_403_sitio.pdb',
#  '4GWS_F6P_A_401_sitio.pdb',
#  '4GWS_F6P_B_401_sitio.pdb',
#  '4GWT_LMR_A_101_sitio.pdb',
#  '4GWU_FDP_A_401_sitio.pdb',
#  '4GWX_F6P_A_401_sitio.pdb',
#  '4GWY_F6P_A_401_sitio.pdb',
#  '4GWY_AMP_A_406_sitio.pdb',
#  '4GWZ_F6P_A_401_sitio.pdb',
#  '4GWZ_F6P_B_401_sitio.pdb',
#  '4GWZ_AMP_A_404_sitio.pdb',
#  '4GWZ_AMP_B_404_sitio.pdb',
#  '4GX1_GLC_B_607_sitio.pdb',
#  '4GX1_GLC_C_608_sitio.pdb',
#  '4GX1_GLC_C_609_sitio.pdb',
#  '4GX1_GLC_D_605_sitio.pdb',
#  '4GX3_F6P_A_401_sitio.pdb',
#  '4GX3_F6P_B_401_sitio.pdb',
#  '4GX4_F6P_A_401_sitio.pdb',
#  '4GX4_F6P_B_401_sitio.pdb',
#  '4GX4_AMP_A_404_sitio.pdb',
#  '4GX4_AMP_B_404_sitio.pdb',
#  '4GX6_AMP_A_404_sitio.pdb',
#  '4GX6_AMP_B_404_sitio.pdb',
#  '4GX6_F6P_A_401_sitio.pdb',
#  '4GX6_F6P_B_401_sitio.pdb',
#  '4GX7_MMA_A_801_sitio.pdb',
#  '4GX7_MMA_B_801_sitio.pdb',
#  '4GX7_MMA_C_801_sitio.pdb',
#  '4GX7_MMA_D_801_sitio.pdb',
#  '4GX7_MMA_E_801_sitio.pdb',
#  '4GX7_MMA_F_801_sitio.pdb',
#  '4GXK_F2A_A_404_sitio.pdb',
#  '4GY2_LAR_B_403_sitio.pdb',
#  '4GY9_ZIP_A_201_sitio.pdb',
#  '4GYF_HSO_A_313_sitio.pdb',
#  '4GYF_HSO_A_314_sitio.pdb',
#  '4GYP_P6G_D_502_sitio.pdb',
#  '4GYU_P6G_A_303_sitio.pdb',
#  '4GYW_UDP_A_1101_sitio.pdb',
#  '4GYW_UDP_C_1101_sitio.pdb',
#  '4GZ3_UDP_A_1101_sitio.pdb',
#  '4GZ3_UDP_C_1101_sitio.pdb',
#  '4GZ7_MHA_A_601_sitio.pdb',
#  '4GZ7_MHA_A_602_sitio.pdb',
#  '4GZ7_MHA_A_603_sitio.pdb',
#  '4GZL_GNP_A_201_sitio.pdb',
#  '4GZL_GNP_B_1000_sitio.pdb',
#  '4GZM_GSP_A_1000_sitio.pdb',
#  '4GZM_GSP_B_1000_sitio.pdb',
#  '4H03_LAR_B_403_sitio.pdb',
#  '4H07_IPH_A_202_sitio.pdb',
#  '4H0N_SAH_A_401_sitio.pdb',
#  '4H0N_SAH_B_401_sitio.pdb',
#  '4H0N_SAH_C_401_sitio.pdb',
#  '4H0N_SAH_D_401_sitio.pdb',
#  '4H0U_UMP_A_301_sitio.pdb',
#  '4H0U_UMP_B_301_sitio.pdb',
#  '4H0U_UMP_C_301_sitio.pdb',
#  '4H0U_UMP_D_301_sitio.pdb',
#  '4H0V_LAR_B_403_sitio.pdb',
#  '4H0W_NTA_A_706_sitio.pdb',
#  '4H0X_LAR_B_403_sitio.pdb',
#  '4H0Y_LAR_B_403_sitio.pdb',
#  '4H0Z_AMU_A_302_sitio.pdb',
#  '4H12_SAH_A_1804_sitio.pdb',
#  '4H16_P6G_A_305_sitio.pdb',
#  '4H16_P6G_A_306_sitio.pdb',
#  '4H1N_CM5_A_504_sitio.pdb',
#  '4H1V_GNP_A_801_sitio.pdb',
#  '4H2B_0XE_A_603_sitio.pdb',
#  '4H2E_BCN_A_314_sitio.pdb',
#  '4H2E_BCN_A_315_sitio.pdb',
#  '4H2E_BCN_B_311_sitio.pdb',
#  '4H2F_ADN_A_601_sitio.pdb',
#  '4H2G_ADN_A_603_sitio.pdb',
#  '4H2I_A12_A_603_sitio.pdb',
#  '4H2R_5HN_A_403_sitio.pdb',
#  '4H2Z_MYS_A_302_sitio.pdb',
#  '4H31_NVA_A_401_sitio.pdb',
#  '4H31_NVA_B_401_sitio.pdb',
#  '4H31_NVA_C_401_sitio.pdb',
#  '4H31_CP_A_402_sitio.pdb',
#  '4H31_CP_B_402_sitio.pdb',
#  '4H31_CP_C_403_sitio.pdb',
#  '4H3P_ANP_A_401_sitio.pdb',
#  '4H3P_ANP_D_401_sitio.pdb',
#  '4H3Q_ANP_A_401_sitio.pdb',
#  '4H3S_DTT_A_916_sitio.pdb',
#  '4H3Y_SAH_A_301_sitio.pdb',
#  '4H3Z_SAH_A_301_sitio.pdb',
#  '4H3Z_SAH_B_301_sitio.pdb',
#  '4H41_PG6_B_403_sitio.pdb',
#  '4H41_PG6_B_404_sitio.pdb',
#  '4H44_UMQ_A_304_sitio.pdb',
#  '4H44_UMQ_A_305_sitio.pdb',
#  '4H44_UMQ_A_307_sitio.pdb',
#  '4H44_UMQ_A_309_sitio.pdb',
#  '4H44_UMQ_F_101_sitio.pdb',
#  '4H44_MYS_A_306_sitio.pdb',
#  '4H44_8K6_A_308_sitio.pdb',
#  '4H44_CLA_B_201_sitio.pdb',
#  '4H44_OCT_F_102_sitio.pdb',
#  '4H44_BCR_G_101_sitio.pdb',
#  '4H4B_11H_A_601_sitio.pdb',
#  '4H55_DBB_A_304_sitio.pdb',
#  '4H55_BDR_A_303_sitio.pdb',
#  '4H5E_IPR_F_402_sitio.pdb',
#  '4H5W_BET_A_403_sitio.pdb',
#  '4H5W_BET_B_405_sitio.pdb',
#  '4H6R_FDA_A_2001_sitio.pdb',
#  '4H6R_FDA_C_2001_sitio.pdb',
#  '4H6U_ACO_A_201_sitio.pdb',
#  '4H6U_ACO_B_201_sitio.pdb',
#  '4H6Z_ACO_A_201_sitio.pdb',
#  '4H6Z_ACO_B_201_sitio.pdb',
#  '4H7V_GLC_A_602_sitio.pdb',
#  '4H7V_GLC_B_7002_sitio.pdb',
#  '4H7Z_GUN_A_401_sitio.pdb',
#  '4H8E_FPP_A_302_sitio.pdb',
#  '4H99_BCL_L_301_sitio.pdb',
#  '4H99_BCL_L_302_sitio.pdb',
#  '4H99_BCL_M_403_sitio.pdb',
#  '4H99_BPH_L_303_sitio.pdb',
#  '4H99_SPO_M_406_sitio.pdb',
#  '4H9G_GNP_A_501_sitio.pdb',
#  '4H9L_BCL_L_301_sitio.pdb',
#  '4H9L_BCL_L_302_sitio.pdb',
#  '4H9L_BCL_M_403_sitio.pdb',
#  '4H9L_BPH_L_303_sitio.pdb',
#  '4HA1_GLC_B_7002_sitio.pdb',
#  '4HA6_PXM_A_609_sitio.pdb',
#  '4HAB_CXS_A_601_sitio.pdb',
#  '4HAB_CXS_A_602_sitio.pdb',
#  '4HAB_CXS_B_601_sitio.pdb',
#  '4HAB_CXS_C_601_sitio.pdb',
#  '4HAB_CXS_C_602_sitio.pdb',
#  '4HAJ_DXC_A_75_sitio.pdb',
#  '4HAR_LDA_A_202_sitio.pdb',
#  '4HAR_LDA_A_204_sitio.pdb',
#  '4HAR_LDA_A_205_sitio.pdb',
#  '4HAR_LDA_A_206_sitio.pdb',
#  '4HAR_LDA_B_201_sitio.pdb',
#  '4HAR_LDA_B_203_sitio.pdb',
#  '4HAR_LDA_B_205_sitio.pdb',
#  '4HAR_LDA_B_206_sitio.pdb',
#  '4HAR_LDA_D_201_sitio.pdb',
#  '4HAR_LDA_D_203_sitio.pdb',
#  '4HAR_LDA_E_202_sitio.pdb',
#  '4HAR_LDA_F_201_sitio.pdb',
#  '4HAR_LDA_F_202_sitio.pdb',
#  '4HAR_LDA_F_203_sitio.pdb',
#  '4HB2_GNP_A_301_sitio.pdb',
#  '4HB3_GNP_A_301_sitio.pdb',
#  '4HB6_DXC_A_75_sitio.pdb',
#  '4HB8_DXC_A_75_sitio.pdb',
#  '4HBF_DXC_A_75_sitio.pdb',
#  '4HBH_BCL_L_301_sitio.pdb',
#  '4HBH_BCL_L_302_sitio.pdb',
#  '4HBH_BCL_M_403_sitio.pdb',
#  '4HBH_BPH_L_303_sitio.pdb',
#  '4HBJ_BPH_L_303_sitio.pdb',
#  '4HBJ_BPH_M_404_sitio.pdb',
#  '4HBJ_SPO_M_406_sitio.pdb',
#  '4HBJ_BCL_L_301_sitio.pdb',
#  '4HBJ_BCL_L_302_sitio.pdb',
#  '4HBJ_BCL_M_403_sitio.pdb',
#  '4HBN_CMP_A_801_sitio.pdb',
#  '4HBV_15E_A_203_sitio.pdb',
#  '4HC3_DXC_A_75_sitio.pdb',
#  '4HC4_SAH_A_401_sitio.pdb',
#  '4HCL_LLH_A_403_sitio.pdb',
#  '4HCL_LLH_B_403_sitio.pdb',
#  '4HCQ_GN1_A_501_sitio.pdb',
#  '4HCQ_GN1_A_502_sitio.pdb',
#  '4HD8_PIT_A_402_sitio.pdb',
#  '4HDA_STL_B_402_sitio.pdb',
#  '4HDK_13X_A_702_sitio.pdb',
#  '4HDK_13X_B_402_sitio.pdb',
#  '4HDL_DXC_A_75_sitio.pdb',
#  '4HDM_PCR_A_801_sitio.pdb',
#  '4HDO_GNP_B_201_sitio.pdb',
#  '4HDQ_GNP_B_201_sitio.pdb',
#  '4HDR_DMD_A_801_sitio.pdb',
#  '4HDR_DMD_C_801_sitio.pdb',
#  '4HDS_IPH_A_801_sitio.pdb',
#  '4HE1_F6P_A_401_sitio.pdb',
#  '4HE2_AMP_A_401_sitio.pdb',
#  '4HEW_2MZ_A_302_sitio.pdb',
#  '4HEW_2MZ_A_303_sitio.pdb',
#  '4HEY_4MZ_A_302_sitio.pdb',
#  '4HEY_4MZ_A_303_sitio.pdb',
#  '4HEY_4MZ_A_304_sitio.pdb',
#  '4HEY_4MZ_A_305_sitio.pdb',
#  '4HEY_4MZ_A_306_sitio.pdb',
#  '4HEY_4MZ_A_307_sitio.pdb',
#  '4HEY_4MZ_A_308_sitio.pdb',
#  '4HEY_4MZ_A_309_sitio.pdb',
#  '4HEY_4MZ_A_310_sitio.pdb',
#  '4HEZ_1MZ_A_302_sitio.pdb',
#  '4HEZ_1MZ_A_303_sitio.pdb',
#  '4HEZ_1MZ_A_304_sitio.pdb',
#  '4HEZ_1MZ_A_306_sitio.pdb',
#  '4HEZ_1MZ_A_307_sitio.pdb',
#  '4HEZ_1MZ_A_308_sitio.pdb',
#  '4HF8_PLG_A_401_sitio.pdb',
#  '4HFN_CIY_A_401_sitio.pdb',
#  '4HG7_NUT_A_201_sitio.pdb',
#  '4HG9_G3P_A_204_sitio.pdb',
#  '4HG9_G3P_C_202_sitio.pdb',
#  '4HGO_KDN_A_202_sitio.pdb',
#  '4HGO_KDN_D_203_sitio.pdb',
#  '4HH4_SAH_A_301_sitio.pdb',
#  '4HH4_SAH_B_301_sitio.pdb',
#  '4HH4_SAH_C_301_sitio.pdb',
#  '4HH4_SAH_D_301_sitio.pdb',
#  '4HH4_SAH_E_301_sitio.pdb',
#  '4HH4_SAH_F_301_sitio.pdb',
#  '4HHH_RUB_A_501_sitio.pdb',
#  '4HHH_RUB_B_501_sitio.pdb',
#  '4HHH_RUB_C_501_sitio.pdb',
#  '4HHH_RUB_D_501_sitio.pdb',
#  '4HHJ_P6G_A_1003_sitio.pdb',
#  '4HHR_BNG_A_714_sitio.pdb',
#  '4HHR_P6G_A_715_sitio.pdb',
#  '4HHS_BNG_A_711_sitio.pdb',
#  '4HHS_P6G_A_712_sitio.pdb',
#  '4HI0_GDP_E_201_sitio.pdb',
#  '4HI0_GDP_F_201_sitio.pdb',
#  '4HI6_3GP_A_201_sitio.pdb',
#  '4HI6_3GP_B_201_sitio.pdb',
#  '4HIS_3MI_A_201_sitio.pdb',
#  '4HJF_C2E_A_603_sitio.pdb',
#  '4HJM_MPO_A_201_sitio.pdb',
#  '4HK6_5NU_A_402_sitio.pdb',
#  '4HK6_5NU_B_402_sitio.pdb',
#  '4HK6_5NU_C_402_sitio.pdb',
#  '4HK6_5NU_D_402_sitio.pdb',
#  '4HK7_URA_A_403_sitio.pdb',
#  '4HK7_URA_B_402_sitio.pdb',
#  '4HK7_URA_C_402_sitio.pdb',
#  '4HK7_URA_D_403_sitio.pdb',
#  '4HKF_ACO_A_201_sitio.pdb',
#  '4HKK_AGI_A_1204_sitio.pdb',
#  '4HKK_AGI_C_1205_sitio.pdb',
#  '4HKM_CXS_B_401_sitio.pdb',
#  '4HKN_LU2_A_1204_sitio.pdb',
#  '4HKV_UNU_A_1006_sitio.pdb',
#  '4HLR_HEZ_A_101_sitio.pdb',
#  '4HLW_TES_A_1001_sitio.pdb',
#  '4HM0_IAC_A_505_sitio.pdb',
#  '4HMI_THP_A_202_sitio.pdb',
#  '4HMJ_THP_A_202_sitio.pdb',
#  '4HMK_BOG_A_606_sitio.pdb',
#  '4HMK_BOG_A_607_sitio.pdb',
#  '4HMK_BOG_A_608_sitio.pdb',
#  '4HMK_BOG_A_609_sitio.pdb',
#  '4HMK_BOG_A_610_sitio.pdb',
#  '4HMK_BOG_B_601_sitio.pdb',
#  '4HMK_BOG_B_602_sitio.pdb',
#  '4HMK_BOG_B_608_sitio.pdb',
#  '4HMK_BOG_B_609_sitio.pdb',
#  '4HMQ_FCE_A_401_sitio.pdb',
#  '4HMQ_FCE_B_401_sitio.pdb',
#  '4HN1_TYD_A_305_sitio.pdb',
#  '4HN1_TYD_B_304_sitio.pdb',
#  '4HN1_TYD_C_303_sitio.pdb',
#  '4HN1_TYD_C_304_sitio.pdb',
#  '4HN1_TDR_C_305_sitio.pdb',
#  '4HN1_TDR_D_303_sitio.pdb',
#  '4HN1_THM_A_306_sitio.pdb',
#  '4HN1_THM_B_305_sitio.pdb',
#  '4HN2_ANP_A_401_sitio.pdb',
#  '4HN4_0JO_B_401_sitio.pdb',
#  '4HN4_BCN_B_405_sitio.pdb',
#  '4HN4_BCN_B_406_sitio.pdb',
#  '4HN4_BCN_B_407_sitio.pdb',
#  '4HNW_IHP_A_901_sitio.pdb',
#  '4HNX_G4P_A_901_sitio.pdb',
#  '4HO2_THM_A_300_sitio.pdb',
#  '4HO2_THM_A_301_sitio.pdb',
#  '4HO3_TTP_A_300_sitio.pdb',
#  '4HO3_TTP_A_301_sitio.pdb',
#  '4HO4_G1P_A_301_sitio.pdb',
#  '4HO4_THM_A_302_sitio.pdb',
#  '4HO4_THM_A_303_sitio.pdb',
#  '4HO4_THM_B_301_sitio.pdb',
#  '4HO4_THM_B_302_sitio.pdb',
#  '4HO5_DAU_A_300_sitio.pdb',
#  '4HO5_DAU_A_301_sitio.pdb',
#  '4HO5_DAU_B_300_sitio.pdb',
#  '4HO5_DAU_B_301_sitio.pdb',
#  '4HO6_UPG_A_300_sitio.pdb',
#  '4HO6_UTP_A_301_sitio.pdb',
#  '4HO8_UPG_A_300_sitio.pdb',
#  '4HO8_UPG_B_300_sitio.pdb',
#  '4HO8_UPG_C_300_sitio.pdb',
#  '4HO8_UPG_D_300_sitio.pdb',
#  '4HO8_THM_A_301_sitio.pdb',
#  '4HO8_THM_B_301_sitio.pdb',
#  '4HO8_THM_C_301_sitio.pdb',
#  '4HO8_THM_D_301_sitio.pdb',
#  '4HO9_UTP_A_301_sitio.pdb',
#  '4HO9_UTP_B_301_sitio.pdb',
#  '4HO9_GDU_A_300_sitio.pdb',
#  '4HO9_GDU_B_300_sitio.pdb',
#  '4HOC_UD1_A_300_sitio.pdb',
#  '4HOC_UD1_B_300_sitio.pdb',
#  '4HOH_2GP_A_107_sitio.pdb',
#  '4HOH_2GP_B_108_sitio.pdb',
#  '4HOH_2GP_C_109_sitio.pdb',
#  '4HOH_2GP_C_110_sitio.pdb',
#  '4HOH_2GP_D_111_sitio.pdb',
#  '4HON_AKG_A_401_sitio.pdb',
#  '4HON_AKG_B_401_sitio.pdb',
#  '4HOZ_GLC_A_703_sitio.pdb',
#  '4HP5_GLC_A_703_sitio.pdb',
#  '4HPD_HCS_A_202_sitio.pdb',
#  '4HPJ_BCN_B_402_sitio.pdb',
#  '4HPU_ANP_I_600_sitio.pdb',
#  '4HPX_BZI_B_401_sitio.pdb',
#  '4HPX_BZI_B_402_sitio.pdb',
#  '4HPX_BZI_B_403_sitio.pdb',
#  '4HPX_0JO_B_404_sitio.pdb',
#  '4HPX_BCN_B_405_sitio.pdb',
#  '4HPX_BCN_B_406_sitio.pdb',
#  '4HPX_BCN_B_407_sitio.pdb',
#  '4HQZ_HED_A_201_sitio.pdb',
#  '4HQZ_HED_B_201_sitio.pdb',
#  '4HR0_PLM_A_405_sitio.pdb',
#  '4HR4_PLM_A_404_sitio.pdb',
#  '4HR5_PLM_A_401_sitio.pdb',
#  '4HR6_AMG_C_301_sitio.pdb',
#  '4HR6_AMG_C_302_sitio.pdb',
#  '4HRQ_AZG_A_201_sitio.pdb',
#  '4HRQ_AZG_B_201_sitio.pdb',
#  '4HRW_AZG_B_202_sitio.pdb',
#  '4HRY_TAM_A_305_sitio.pdb',
#  '4HS7_P33_A_502_sitio.pdb',
#  '4HS7_P33_B_502_sitio.pdb',
#  '4HS9_PE4_A_405_sitio.pdb',
#  '4HSJ_6PC_A_203_sitio.pdb',
#  '4HSL_3HA_A_203_sitio.pdb',
#  '4HSX_BML_A_206_sitio.pdb',
#  '4HSX_BML_B_203_sitio.pdb',
#  '4HT3_BCN_A_302_sitio.pdb',
#  '4HT3_BCN_B_405_sitio.pdb',
#  '4HT3_BCN_B_406_sitio.pdb',
#  '4HT3_BCN_B_407_sitio.pdb',
#  '4HT3_PG5_A_306_sitio.pdb',
#  '4HTH_THP_A_201_sitio.pdb',
#  '4HUP_MLA_X_304_sitio.pdb',
#  '4HUP_MLA_X_305_sitio.pdb',
#  '4HUR_ACO_A_301_sitio.pdb',
#  '4HUR_ACO_B_301_sitio.pdb',
#  '4HUR_ACO_C_301_sitio.pdb',
#  '4HV3_MLA_A_303_sitio.pdb',
#  '4HV3_MLA_A_304_sitio.pdb',
#  '4HV4_AMP_A_501_sitio.pdb',
#  '4HV4_AMP_B_501_sitio.pdb',
#  '4HV7_MLA_X_303_sitio.pdb',
#  '4HVC_ANP_A_1601_sitio.pdb',
#  '4HVC_ANP_B_1601_sitio.pdb',
#  '4HVC_HFG_A_1602_sitio.pdb',
#  '4HVC_HFG_B_1602_sitio.pdb',
#  '4HVD_PHU_A_1201_sitio.pdb',
#  '4HVJ_AMP_A_300_sitio.pdb',
#  '4HVK_PMP_A_404_sitio.pdb',
#  '4HVR_SAL_A_203_sitio.pdb',
#  '4HWB_NHE_A_403_sitio.pdb',
#  '4HWB_NHE_A_404_sitio.pdb',
#  '4HWB_NHE_A_405_sitio.pdb',
#  '4HWB_NHE_H_306_sitio.pdb',
#  '4HWB_NHE_H_307_sitio.pdb',
#  '4HWH_MLA_A_301_sitio.pdb',
#  '4HWH_MLA_C_301_sitio.pdb',
#  '4HWK_SFY_A_807_sitio.pdb',
#  '4HWK_SFY_B_806_sitio.pdb',
#  '4HWK_SFY_C_804_sitio.pdb',
#  '4HWK_SFY_D_803_sitio.pdb',
#  '4HX0_BU1_A_209_sitio.pdb',
#  '4HX0_BU1_A_210_sitio.pdb',
#  '4HX0_BU1_A_212_sitio.pdb',
#  '4HX0_BU1_A_213_sitio.pdb',
#  '4HX0_BU1_A_214_sitio.pdb',
#  '4HX0_BU1_A_215_sitio.pdb',
#  '4HX0_BU1_A_217_sitio.pdb',
#  '4HX0_BU1_A_218_sitio.pdb',
#  '4HX0_BU1_A_219_sitio.pdb',
#  '4HX0_BU1_A_220_sitio.pdb',
#  '4HXE_HEZ_B_704_sitio.pdb',
#  '4HXE_HEZ_B_705_sitio.pdb',
#  '4HXE_HEZ_B_706_sitio.pdb',
#  '4HXE_HEZ_B_707_sitio.pdb',
#  '4HXE_HEZ_B_708_sitio.pdb',
#  '4HXE_HEZ_B_709_sitio.pdb',
#  '4HXV_AMP_A_402_sitio.pdb',
#  '4HXY_ACA_B_502_sitio.pdb',
#  '4HYF_NCA_A_1201_sitio.pdb',
#  '4HYF_NCA_B_1201_sitio.pdb',
#  '4HYF_NCA_C_1201_sitio.pdb',
#  '4HYO_HEZ_A_205_sitio.pdb',
#  '4HYO_HEZ_A_206_sitio.pdb',
#  '4HYO_HEZ_B_201_sitio.pdb',
#  '4HYO_HEZ_B_202_sitio.pdb',
#  '4HYO_HEZ_C_201_sitio.pdb',
#  '4HYO_HEZ_C_202_sitio.pdb',
#  '4HYO_HEZ_D_201_sitio.pdb',
#  '4HYO_HEZ_D_202_sitio.pdb',
#  '4HYO_HEZ_E_205_sitio.pdb',
#  '4HYO_HEZ_F_201_sitio.pdb',
#  '4HYO_HEZ_G_201_sitio.pdb',
#  '4HYO_HEZ_H_201_sitio.pdb',
#  '4HYV_FDP_A_1004_sitio.pdb',
#  '4HYV_FDP_B_1004_sitio.pdb',
#  '4HYW_FDP_B_503_sitio.pdb',
#  '4HYW_FDP_A_503_sitio.pdb',
#  '4HZ3_HEZ_D_205_sitio.pdb',
#  '4HZ3_HEZ_D_206_sitio.pdb',
#  '4HZ3_HEZ_D_207_sitio.pdb',
#  '4HZ3_HEZ_C_201_sitio.pdb',
#  '4HZ3_HEZ_C_202_sitio.pdb',
#  '4HZ3_HEZ_C_203_sitio.pdb',
#  '4HZ3_HEZ_A_201_sitio.pdb',
#  '4HZ3_HEZ_A_202_sitio.pdb',
#  '4HZ3_HEZ_A_203_sitio.pdb',
#  '4HZ3_HEZ_B_201_sitio.pdb',
#  '4HZ3_HEZ_B_202_sitio.pdb',
#  '4HZ3_HEZ_B_203_sitio.pdb',
#  '4HZ3_HEZ_E_205_sitio.pdb',
#  '4HZ3_HEZ_E_206_sitio.pdb',
#  '4HZ3_HEZ_F_201_sitio.pdb',
#  '4HZ3_HEZ_F_202_sitio.pdb',
#  '4HZ3_HEZ_F_203_sitio.pdb',
#  '4HZ3_HEZ_G_201_sitio.pdb',
#  '4HZ3_HEZ_G_202_sitio.pdb',
#  '4HZ3_HEZ_H_201_sitio.pdb',
#  '4HZE_BEN_A_403_sitio.pdb',
#  '4HZE_BEN_B_403_sitio.pdb',
#  '4HZE_BEN_C_403_sitio.pdb',
#  '4HZF_CMP_A_301_sitio.pdb',
#  '4HZF_CMP_A_302_sitio.pdb',
#  '4HZF_CMP_B_301_sitio.pdb',
#  '4I01_CMP_A_301_sitio.pdb',
#  '4I01_CMP_A_302_sitio.pdb',
#  '4I01_CMP_B_301_sitio.pdb',
#  '4I02_CMP_A_301_sitio.pdb',
#  '4I02_CMP_A_302_sitio.pdb',
#  '4I02_CMP_B_301_sitio.pdb',
#  '4I02_CMP_B_302_sitio.pdb',
#  '4I02_CMP_C_301_sitio.pdb',
#  '4I02_CMP_D_301_sitio.pdb',
#  '4I02_CMP_D_302_sitio.pdb',
#  '4I02_CMP_E_301_sitio.pdb',
#  '4I02_CMP_F_301_sitio.pdb',
#  '4I06_BEN_A_403_sitio.pdb',
#  '4I06_BEN_B_403_sitio.pdb',
#  '4I06_BEN_C_403_sitio.pdb',
#  '4I09_CMP_A_301_sitio.pdb',
#  '4I09_CMP_B_301_sitio.pdb',
#  '4I0A_CMP_A_301_sitio.pdb',
#  '4I0A_CMP_A_302_sitio.pdb',
#  '4I0A_CMP_B_301_sitio.pdb',
#  '4I0B_CMP_A_301_sitio.pdb',
#  '4I0B_CMP_A_302_sitio.pdb',
#  '4I0B_CMP_B_301_sitio.pdb',
#  '4I0U_LMT_A_403_sitio.pdb',
#  '4I0U_LMT_B_406_sitio.pdb',
#  '4I13_FOL_A_201_sitio.pdb',
#  '4I1N_FOL_A_201_sitio.pdb',
#  '4I1O_GDP_A_202_sitio.pdb',
#  '4I1O_GDP_C_202_sitio.pdb',
#  '4I1O_GDP_E_202_sitio.pdb',
#  '4I1O_GDP_G_202_sitio.pdb',
#  '4I1R_LZU_A_801_sitio.pdb',
#  '4I27_D3T_A_602_sitio.pdb',
#  '4I2B_APC_A_603_sitio.pdb',
#  '4I2C_APC_A_602_sitio.pdb',
#  '4I2D_APC_A_603_sitio.pdb',
#  '4I2E_APC_A_603_sitio.pdb',
#  '4I2H_APC_A_605_sitio.pdb',
#  '4I2J_DCP_A_601_sitio.pdb',
#  '4I30_ABU_A_303_sitio.pdb',
#  '4I30_ADE_A_304_sitio.pdb',
#  '4I35_HEX_A_506_sitio.pdb',
#  '4I35_HEX_A_507_sitio.pdb',
#  '4I35_OCT_A_508_sitio.pdb',
#  '4I35_OCT_A_509_sitio.pdb',
#  '4I3G_MPO_A_910_sitio.pdb',
#  '4I3G_MPO_B_906_sitio.pdb',
#  '4I41_MIX_A_500_sitio.pdb',
#  '4I41_MIX_A_501_sitio.pdb',
#  '4I4C_1PG_A_501_sitio.pdb',
#  '4I4C_1PG_B_501_sitio.pdb',
#  '4I4C_6NA_A_502_sitio.pdb',
#  '4I4C_6NA_B_503_sitio.pdb',
#  '4I4J_TAR_A_201_sitio.pdb',
#  '4I4J_TAR_B_201_sitio.pdb',
#  '4I4J_TAR_C_201_sitio.pdb',
#  '4I4U_GLA_A_201_sitio.pdb',
#  '4I4U_GLA_A_202_sitio.pdb',
#  '4I4U_GLA_A_203_sitio.pdb',
#  '4I4U_GLA_B_201_sitio.pdb',
#  '4I4U_GLA_B_202_sitio.pdb',
#  '4I4U_GLA_D_201_sitio.pdb',
#  '4I4U_GLA_D_202_sitio.pdb',
#  '4I4U_GLA_D_203_sitio.pdb',
#  '4I4V_NGA_A_201_sitio.pdb',
#  '4I4V_NGA_A_202_sitio.pdb',
#  '4I4V_NGA_B_201_sitio.pdb',
#  '4I4V_NGA_B_202_sitio.pdb',
#  '4I4V_NGA_D_201_sitio.pdb',
#  '4I4V_NGA_D_202_sitio.pdb',
#  '4I51_SAH_A_3001_sitio.pdb',
#  '4I51_SAH_B_3001_sitio.pdb',
#  '4I59_CYH_A_502_sitio.pdb',
#  '4I59_CYH_B_502_sitio.pdb',
#  '4I59_CYH_C_502_sitio.pdb',
#  '4I59_CYH_D_502_sitio.pdb',
#  '4I5M_R78_A_401_sitio.pdb',
#  '4I5V_B4P_A_401_sitio.pdb',
#  '4I5V_B4P_B_401_sitio.pdb',
#  '4I5W_AMP_A_402_sitio.pdb',
#  '4I5W_AMP_A_403_sitio.pdb',
#  '4I5W_AMP_B_401_sitio.pdb',
#  '4I5W_AMP_B_402_sitio.pdb',
#  '4I5X_FLF_A_401_sitio.pdb',
#  '4I6A_HMG_A_501_sitio.pdb',
#  '4I6Q_PHU_A_1201_sitio.pdb',
#  '4I6Y_MEV_A_501_sitio.pdb',
#  '4I6Y_MEV_B_1001_sitio.pdb',
#  '4I72_UA2_A_402_sitio.pdb',
#  '4I72_UA2_B_402_sitio.pdb',
#  '4I76_OC9_A_301_sitio.pdb',
#  '4I76_OC9_A_302_sitio.pdb',
#  '4I7J_BNZ_A_202_sitio.pdb',
#  '4I7J_BNZ_B_202_sitio.pdb',
#  '4I7J_HED_A_210_sitio.pdb',
#  '4I7K_HED_A_207_sitio.pdb',
#  '4I7L_HED_A_209_sitio.pdb',
#  '4I7L_IPH_A_202_sitio.pdb',
#  '4I7L_IPH_B_202_sitio.pdb',
#  '4I7M_HED_A_206_sitio.pdb',
#  '4I7N_HED_A_209_sitio.pdb',
#  '4I7O_HED_A_209_sitio.pdb',
#  '4I7P_ES3_A_202_sitio.pdb',
#  '4I7P_ES3_B_202_sitio.pdb',
#  '4I7P_HED_A_210_sitio.pdb',
#  '4I7Q_HED_A_212_sitio.pdb',
#  '4I7R_HED_A_210_sitio.pdb',
#  '4I7S_HED_A_208_sitio.pdb',
#  '4I7T_HED_A_208_sitio.pdb',
#  '4I7Z_MYS_A_304_sitio.pdb',
#  '4I7Z_8K6_A_305_sitio.pdb',
#  '4I7Z_CLA_B_201_sitio.pdb',
#  '4I7Z_OCT_F_101_sitio.pdb',
#  '4I7Z_BCR_G_101_sitio.pdb',
#  '4I7Z_UMQ_A_306_sitio.pdb',
#  '4I7Z_UMQ_A_307_sitio.pdb',
#  '4I7Z_UMQ_A_308_sitio.pdb',
#  '4I89_1FL_A_201_sitio.pdb',
#  '4I89_1FL_B_201_sitio.pdb',
#  '4I8V_BHF_A_602_sitio.pdb',
#  '4I8V_BHF_B_602_sitio.pdb',
#  '4I8V_BHF_C_601_sitio.pdb',
#  '4I8V_BHF_D_601_sitio.pdb',
#  '4I8X_6P3_A_401_sitio.pdb',
#  '4I8X_6P3_B_401_sitio.pdb',
#  '4I8X_6P3_C_401_sitio.pdb',
#  '4I8X_6P3_D_401_sitio.pdb',
#  '4I8X_6P3_E_401_sitio.pdb',
#  '4I8X_6P3_F_401_sitio.pdb',
#  '4I8X_6P3_G_401_sitio.pdb',
#  '4I8X_6P3_H_401_sitio.pdb',
#  '4I90_CHT_A_502_sitio.pdb',
#  '4I90_CHT_A_503_sitio.pdb',
#  '4I91_CM5_A_504_sitio.pdb',
#  '4I94_ANP_A_401_sitio.pdb',
#  '4I94_ANP_B_401_sitio.pdb',
#  '4I9A_NCN_A_301_sitio.pdb',
#  '4I9A_NCN_B_301_sitio.pdb',
#  '4I9T_INS_A_502_sitio.pdb',
#  '4I9T_INS_A_503_sitio.pdb',
#  '4IA2_BIV_A_501_sitio.pdb',
#  '4IA6_EIC_A_608_sitio.pdb',
#  '4IA7_BIV_A_501_sitio.pdb',
#  '4IAA_RTZ_A_401_sitio.pdb',
#  '4IAC_ACP_A_403_sitio.pdb',
#  '4IAL_THP_A_202_sitio.pdb',
#  '4IAO_APR_A_602_sitio.pdb',
#  '4IAO_APR_B_602_sitio.pdb',
#  '4IAR_ERM_A_2001_sitio.pdb',
#  '4IB6_DAO_A_201_sitio.pdb',
#  '4IB7_CAT_A_201_sitio.pdb',
#  '4IB8_SDS_A_201_sitio.pdb',
#  '4IB9_CAT_A_201_sitio.pdb',
#  '4IBA_SDS_A_201_sitio.pdb',
#  '4IBL_BEN_H_301_sitio.pdb',
#  '4IC0_GDE_A_401_sitio.pdb',
#  '4IC0_GDE_C_401_sitio.pdb',
#  '4IC7_ANP_A_501_sitio.pdb',
#  '4IC7_ANP_D_501_sitio.pdb',
#  '4ICA_7PE_A_201_sitio.pdb',
#  '4ICA_7PE_B_201_sitio.pdb',
#  '4ICL_T27_A_601_sitio.pdb',
#  '4ID0_GSF_B_302_sitio.pdb',
#  '4ID1_LF0_A_301_sitio.pdb',
#  '4ID5_T27_A_601_sitio.pdb',
#  '4ID5_1FF_A_609_sitio.pdb',
#  '4IDK_T27_A_601_sitio.pdb',
#  '4IDN_GNP_A_501_sitio.pdb',
#  '4IDN_GNP_B_501_sitio.pdb',
#  '4IDO_GDP_A_501_sitio.pdb',
#  '4IDO_GDP_B_501_sitio.pdb',
#  '4IDP_GNP_A_501_sitio.pdb',
#  '4IDP_GNP_B_501_sitio.pdb',
#  '4IDP_GNP_C_501_sitio.pdb',
#  '4IDP_GNP_D_501_sitio.pdb',
#  '4IDQ_P6G_A_504_sitio.pdb',
#  '4IDQ_P6G_B_504_sitio.pdb',
#  '4IDQ_P6G_C_504_sitio.pdb',
#  '4IDQ_P6G_D_504_sitio.pdb',
#  '4IDQ_GDP_A_501_sitio.pdb',
#  '4IDQ_GDP_B_501_sitio.pdb',
#  '4IDQ_GDP_C_501_sitio.pdb',
#  '4IDQ_GDP_D_501_sitio.pdb',
#  '4IDY_HED_A_301_sitio.pdb',
#  '4IDZ_OGA_A_601_sitio.pdb',
#  '4IE0_PD2_A_603_sitio.pdb',
#  '4IE2_BEN_A_403_sitio.pdb',
#  '4IE2_BEN_B_403_sitio.pdb',
#  '4IE2_BEN_C_403_sitio.pdb',
#  '4IE3_BEN_A_403_sitio.pdb',
#  '4IE3_BEN_B_403_sitio.pdb',
#  '4IE3_BEN_C_403_sitio.pdb',
#  '4IE7_RHN_A_602_sitio.pdb',
#  '4IEE_AGS_A_502_sitio.pdb',
#  '4IEN_GDP_A_202_sitio.pdb',
#  '4IEN_GDP_B_203_sitio.pdb',
#  '4IEN_GDP_C_202_sitio.pdb',
#  '4IEN_GDP_D_203_sitio.pdb',
#  '4IF5_ACO_A_201_sitio.pdb',
#  '4IF6_APR_A_602_sitio.pdb',
#  '4IFV_T27_A_601_sitio.pdb',
#  '4IFY_T27_A_601_sitio.pdb',
#  '4IFZ_AMP_A_501_sitio.pdb',
#  '4IG1_AMP_A_501_sitio.pdb',
#  '4IG3_T27_A_601_sitio.pdb',
#  '4IG6_SAH_A_301_sitio.pdb',
#  '4IG8_DTP_A_403_sitio.pdb',
#  '4IGH_ORO_A_502_sitio.pdb',
#  '4IGO_AKG_A_1001_sitio.pdb',
#  '4IGQ_OGA_A_502_sitio.pdb',
#  '4IH3_PDC_A_402_sitio.pdb',
#  '4IH3_PDC_B_402_sitio.pdb',
#  '4IH3_PDC_C_402_sitio.pdb',
#  '4IH3_PDC_D_402_sitio.pdb',
#  '4IH3_PDC_E_402_sitio.pdb',
#  '4IH3_PDC_F_402_sitio.pdb',
#  '4II8_010_A_210_sitio.pdb',
#  '4IIR_ANP_A_1101_sitio.pdb',
#  '4IIR_ANP_B_1101_sitio.pdb',
#  '4IJ6_SEP_A_301_sitio.pdb',
#  '4IJ6_SEP_B_301_sitio.pdb',
#  '4IJN_AMP_A_402_sitio.pdb',
#  '4IJN_AMP_B_402_sitio.pdb',
#  '4IJT_DTT_A_303_sitio.pdb',
#  '4IK7_IMN_A_201_sitio.pdb',
#  '4IK7_IMN_B_201_sitio.pdb',
#  '4IKE_AMP_A_301_sitio.pdb',
#  '4IKE_AMP_B_301_sitio.pdb',
#  '4IKI_IMN_A_201_sitio.pdb',
#  '4IKI_IMN_B_201_sitio.pdb',
#  '4IKJ_SUZ_A_201_sitio.pdb',
#  '4IKJ_SUZ_B_201_sitio.pdb',
#  '4IKK_SUZ_A_201_sitio.pdb',
#  '4IKK_SUZ_B_201_sitio.pdb',
#  '4IKL_SUZ_A_201_sitio.pdb',
#  '4IKL_SUZ_B_201_sitio.pdb',
#  '4IKP_4IK_B_501_sitio.pdb',
#  '4IKP_4IK_C_501_sitio.pdb',
#  '4IKP_4IK_D_501_sitio.pdb',
#  '4IKW_OLA_A_611_sitio.pdb',
#  '4ILE_GDP_A_201_sitio.pdb',
#  '4IM7_CS2_A_501_sitio.pdb',
#  '4IMA_FBP_A_603_sitio.pdb',
#  '4IMA_FBP_B_603_sitio.pdb',
#  '4IMA_FBP_C_603_sitio.pdb',
#  '4IMA_FBP_D_603_sitio.pdb',
#  '4IMA_ADN_D_604_sitio.pdb',
#  '4IMF_ME2_A_302_sitio.pdb',
#  '4IMF_ME2_B_302_sitio.pdb',
#  '4IMF_ME2_B_303_sitio.pdb',
#  '4IMG_ME2_A_502_sitio.pdb',
#  '4IMG_ME2_A_503_sitio.pdb',
#  '4IMG_ME2_A_504_sitio.pdb',
#  '4IMG_ME2_A_505_sitio.pdb',
#  '4IMG_ME2_A_506_sitio.pdb',
#  '4IMG_ME2_B_502_sitio.pdb',
#  '4IMG_ME2_B_503_sitio.pdb',
#  '4IMG_ME2_B_504_sitio.pdb',
#  '4IMN_1PG_A_201_sitio.pdb',
#  '4IMT_H4B_A_802_sitio.pdb',
#  '4IMT_H4B_B_802_sitio.pdb',
#  '4IMU_H4B_A_802_sitio.pdb',
#  '4IMU_H4B_A_809_sitio.pdb',
#  '4IMW_H4B_A_802_sitio.pdb',
#  '4IMW_H4B_A_805_sitio.pdb',
#  '4IMX_H4B_A_502_sitio.pdb',
#  '4IMX_H4B_B_502_sitio.pdb',
#  '4IN5_LDA_L_301_sitio.pdb',
#  '4IN5_LDA_L_302_sitio.pdb',
#  '4IN5_LDA_M_404_sitio.pdb',
#  '4IN5_LDA_M_412_sitio.pdb',
#  '4IN5_LDA_H_304_sitio.pdb',
#  '4IN5_LDA_H_309_sitio.pdb',
#  '4IN5_BPH_L_303_sitio.pdb',
#  '4IN5_BPH_L_313_sitio.pdb',
#  '4IN5_BCL_L_305_sitio.pdb',
#  '4IN5_BCL_M_402_sitio.pdb',
#  '4IN5_BCL_M_403_sitio.pdb',
#  '4IN5_HTO_L_307_sitio.pdb',
#  '4IN5_HTO_H_308_sitio.pdb',
#  '4IN5_SPO_M_407_sitio.pdb',
#  '4IN6_BCL_L_303_sitio.pdb',
#  '4IN6_BCL_L_308_sitio.pdb',
#  '4IN6_BCL_M_401_sitio.pdb',
#  '4IN6_BCL_M_402_sitio.pdb',
#  '4IN6_HTO_L_305_sitio.pdb',
#  '4IN6_LDA_M_403_sitio.pdb',
#  '4IN6_LDA_M_404_sitio.pdb',
#  '4IN6_LDA_M_413_sitio.pdb',
#  '4IN6_SPO_M_408_sitio.pdb',
#  '4IN6_BPH_L_301_sitio.pdb',
#  '4IN6_BPH_M_406_sitio.pdb',
#  '4IN7_LDA_L_302_sitio.pdb',
#  '4IN7_LDA_L_303_sitio.pdb',
#  '4IN7_LDA_L_304_sitio.pdb',
#  '4IN7_LDA_M_403_sitio.pdb',
#  '4IN7_LDA_M_404_sitio.pdb',
#  '4IN7_HTO_L_308_sitio.pdb',
#  '4IN7_HTO_L_309_sitio.pdb',
#  '4IN7_BPH_M_406_sitio.pdb',
#  '4IN7_BPH_M_412_sitio.pdb',
#  '4IN7_SPO_M_408_sitio.pdb',
#  '4IN7_BCL_L_301_sitio.pdb',
#  '4IN7_BCL_L_306_sitio.pdb',
#  '4IN7_BCL_M_401_sitio.pdb',
#  '4IN7_BCL_M_402_sitio.pdb',
#  '4INE_SAH_A_501_sitio.pdb',
#  '4INE_SAH_B_501_sitio.pdb',
#  '4INE_OPE_A_502_sitio.pdb',
#  '4INE_OPE_B_502_sitio.pdb',
#  '4INF_OXD_B_408_sitio.pdb',
#  '4INF_OXD_C_406_sitio.pdb',
#  '4INF_OXD_D_404_sitio.pdb',
#  '4INI_AMP_A_201_sitio.pdb',
#  '4INI_AMP_B_201_sitio.pdb',
#  '4INI_PG5_B_202_sitio.pdb',
#  '4INJ_LMS_A_401_sitio.pdb',
#  ...]

# %%
print(len(pdb_files))
# Out:
# 71709

# %%
#################################
# AGRUPAMIENTO Y PROCESAMIENTO  #
#################################

# Ruta de la carpeta de entrada con archivos PDB
input_folder = "/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina"

# Ruta de salida para los archivos CSV de USR
output_folder = "/content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/USR_sitios_de_union/Output_USR_sitios_1"
os.makedirs(output_folder, exist_ok=True)


sitios_por_nombre = defaultdict(list)
pdb_files = sorted(glob.glob(os.path.join(input_folder, "*.pdb")))
print(len(pdb_files))
# Out:
# 71709

# %%
pdb_files
# Out:
# ['/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/101M_NBN_A_156_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/103M_NBN_A_156_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/104M_NBN_A_156_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/105M_NBN_A_156_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/107M_NBN_A_156_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/111M_NBN_A_156_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/121P_GCP_A_167_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/12AS_AMP_A_332_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/12AS_AMP_B_332_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/13GS_SAS_A_211_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/13GS_SAS_B_211_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/13PK_3PG_A_423_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/13PK_3PG_B_423_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/17GS_GTX_A_210_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/17GS_GTX_B_210_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/181L_BNZ_A_400_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/181L_HED_A_170_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/182L_HED_A_170_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/183L_HED_A_170_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/184L_HED_A_170_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/185L_HED_A_170_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/185L_IND_A_400_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/186L_HED_A_170_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/187L_PXY_A_400_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/188L_HED_A_170_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/188L_OXE_A_400_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/191L_HED_A_170_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A0G_PMP_A_285_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A0G_PMP_B_285_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A0J_BEN_A_246_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A0J_BEN_B_246_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A0J_BEN_C_246_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A0J_BEN_D_246_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A0R_FAR_G_72_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A27_EST_A_350_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A28_STR_A_1_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A28_STR_B_2_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A29_TFP_A_153_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A29_TFP_A_154_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A2B_GSP_A_538_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A2T_THP_A_151_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A2U_THP_A_151_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A3T_THP_A_151_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A3V_THP_A_151_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A3W_FBP_A_1007_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A3W_FBP_B_1008_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A3W_PGA_A_1005_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A3W_PGA_B_1006_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A3X_PGA_A_1005_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A3X_PGA_B_1006_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A4G_ZMR_A_466_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A4G_ZMR_B_466_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A4H_GDM_A_300_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A4M_PRH_A_354_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A4M_PRH_B_854_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A4M_PRH_C_1354_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A4M_PRH_D_1854_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A4R_GDP_A_200_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A4R_GNH_B_400_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A52_EST_A_1_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A52_EST_B_2_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A53_IGP_A_300_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A5B_IGP_A_271_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A5Z_FBP_A_353_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A5Z_FBP_A_354_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A5Z_OXM_A_355_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A65_PYE_A_900_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A69_FMB_A_240_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A69_FMB_B_240_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A69_FMB_C_240_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A82_DNN_A_801_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A8I_GLS_A_998_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A95_GUN_B_304_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A95_GUN_C_303_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A95_PCP_B_301_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A95_PCP_C_302_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A96_PCP_B_301_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A96_PCP_C_302_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A96_XAN_B_304_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1A96_XAN_C_303_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1
sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1DPO_BEN_A_249_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1DQ8_DTT_B_302_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1DQ8_DTT_C_301_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1DQ9_HMG_A_101_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1DQ9_HMG_B_102_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1DQ9_HMG_C_103_sitio.pdb',
#  '/content/drive/MyDrive/TFM/T2/TOT_ligandos_sitios/TOTAL/TOTAL_PDB/sitios_pdb_proteina/1DQ9_HMG_D_104_sitio.pdb',
#  ...]

# %%
for filepath in pdb_files:
    base = os.path.basename(filepath)
    if base in nombre_instancias_sitios:
      parts = base.split("_")
      if len(parts) < 2:

        # Si no se puede dividir correctamente, se ignora
        continue
      ligand_name = parts[1]
      sitios_por_nombre[ligand_name].append(filepath)

# 2. Procesar cada grupo y generar un CSV para cada ligando
for ligand_name, archivos in sitios_por_nombre.items():
    output_path = os.path.join(output_folder, f"USR_{ligand_name}_sitio.csv")
    with open(output_path, 'w') as out:
        out.write("conformation," + ",".join([f"USR_{i+1}" for i in range(12)]) + "\n")
        for pdb_file in tqdm(archivos, desc=f"Procesando sitios de {ligand_name}"):
            try:
                mol = readPDBLigand(pdb_file)
                descriptor = getUSRDescriptor(mol)
                desc_line = ",".join([f"{d:.5f}" for d in descriptor])
                out.write(f"{os.path.basename(pdb_file)},{desc_line}\n")
            except Exception as e:
                print(f"Error en {pdb_file}: {e}")
# Out:
# Procesando sitios de NBN: 100%|██████████| 16/16 [00:06<00:00,  2.43it/s]
# Procesando sitios de GCP: 100%|██████████| 123/123 [00:51<00:00,  2.38it/s]
# Procesando sitios de AMP: 100%|██████████| 1174/1174 [07:06<00:00,  2.75it/s]
# Procesando sitios de SAS: 100%|██████████| 13/13 [00:02<00:00,  4.50it/s]
# Procesando sitios de 3PG: 100%|██████████| 121/121 [00:26<00:00,  4.63it/s]
# Procesando sitios de GTX: 100%|██████████| 78/78 [00:16<00:00,  4.78it/s]
# Procesando sitios de BNZ: 100%|██████████| 17/17 [00:03<00:00,  4.87it/s]
# Procesando sitios de HED: 100%|██████████| 170/170 [00:33<00:00,  5.00it/s]
# Procesando sitios de IND: 100%|██████████| 41/41 [00:08<00:00,  4.64it/s]
# Procesando sitios de PXY: 100%|██████████| 4/4 [00:00<00:00,  4.05it/s]
# Procesando sitios de OXE: 100%|██████████| 11/11 [00:02<00:00,  4.79it/s]
# Procesando sitios de PMP: 100%|██████████| 196/196 [00:42<00:00,  4.63it/s]
# Procesando sitios de BEN: 100%|██████████| 513/513 [01:47<00:00,  4.79it/s]
# Procesando sitios de FAR: 100%|██████████| 18/18 [00:03<00:00,  4.66it/s]
# Procesando sitios de EST: 100%|██████████| 84/84 [00:18<00:00,  4.61it/s]
# Procesando sitios de STR: 100%|██████████| 48/48 [00:10<00:00,  4.37it/s]
# Procesando sitios de TFP: 100%|██████████| 27/27 [00:05<00:00,  4.62it/s]
# Procesando sitios de GSP: 100%|██████████| 139/139 [00:30<00:00,  4.57it/s]
# Procesando sitios de THP: 100%|██████████| 206/206 [00:44<00:00,  4.60it/s]
# Procesando sitios de FBP: 100%|██████████| 452/452 [01:36<00:00,  4.67it/s]
# Procesando sitios de C0N: 100%|██████████| 3/3 [00:00<00:00,  4.10it/s]
# Procesando sitios de 67I: 100%|██████████| 10/10 [00:02<00:00,  4.23it/s]
# Procesando sitios de 64X: 100%|██████████| 5/5 [00:01<00:00,  4.79it/s]
# Procesando sitios de JL3: 100%|██████████| 5/5 [00:01<00:00,  4.14it/s]
# Procesando sitios de VZ6: 100%|██████████| 2/2 [00:00<00:00,  2.23it/s]
# Procesando sitios de XP6: 100%|██████████| 4/4 [00:00<00:00,  4.69it/s]
# Procesando sitios de HCZ: 100%|██████████| 2/2 [00:00<00:00,  5.24it/s]
# Procesando sitios de ZP2: 100%|██████████| 6/6 [00:01<00:00,  4.65it/s]
# Procesando sitios de YNK: 100%|██████████| 3/3 [00:00<00:00,  5.30it/s]
# Procesando sitios de GOQ: 100%|██████████| 6/6 [00:01<00:00,  3.79it/s]
# Procesando sitios de JQ9: 100%|██████████| 2/2 [00:00<00:00,  4.49it/s]
# Procesando sitios de RTO: 100%|██████████| 13/13 [00:03<00:00,  4.23it/s]
# Procesando sitios de ZWY: 100%|██████████| 2/2 [00:00<00:00,  4.48it/s]
# Procesando sitios de ZNI: 100%|██████████| 30/30 [00:07<00:00,  4.13it/s]
# Procesando sitios de B40: 100%|██████████| 2/2 [00:00<00:00,  4.62it/s]

# %%
import os
import glob
from collections import defaultdict
from tqdm import tqdm
import math

#############################
# LECTOR PDB Y DESCRIPTORES #
#############################

# --------- LECTOR PDB ---------
class Atom:
    def __init__(self, x, y, z):
        self.x = float(x)
        self.y = float(y)
        self.z = float(z)

    def getXCoordinate(self):
        return self.x
    def getYCoordinate(self):
        return self.y
    def getZCoordinate(self):
        return self.z

class Molecule:
    def __init__(self):
        self.atoms = []

    def addAtom(self, atom):
        self.atoms.append(atom)

    def getAtoms(self):
        return self.atoms
    def getAtom(self, i):
        return self.atoms[i]

def readPDBLigand(filepath):
    molecule = Molecule()
    with open(filepath, 'r') as f:
        for line in f:
            if line.startswith("HETATM") or line.startswith("ATOM"):
                try:
                    x = float(line[30:38])
                    y = float(line[38:46])
                    z = float(line[46:54])
                    molecule.addAtom(Atom(x, y, z))
                except Exception as ex:
                    # Si ocurre algún error al convertir las coordenadas, se salta la línea.
                    continue
    return molecule

# --------- CÓDIGO USR ---------
class Point:
    def __init__(self, x=0, y=0, z=0):
        self.xCoordinate = x
        self.yCoordinate = y
        self.zCoordinate = z

class AtomIndexAndDistance:
    def __init__(self, index, distance):
        self.index = index
        self.distance = distance

class USR:
    def CalculateCentroid(self, aMolecule):
        centroid = Point()
        atoms = aMolecule.getAtoms()
        if not atoms:
            return centroid
        sx, sy, sz = 0.0, 0.0, 0.0
        for atom in atoms:
            sx += atom.getXCoordinate()
            sy += atom.getYCoordinate()
            sz += atom.getZCoordinate()
        n = len(atoms)
        centroid.xCoordinate = sx / n
        centroid.yCoordinate = sy / n
        centroid.zCoordinate = sz / n
        return centroid

    def EuclideanDistanceMeasure(self, aMolecule, point, i):
        atom = aMolecule.getAtom(i)
        dx = atom.getXCoordinate() - point.xCoordinate
        dy = atom.getYCoordinate() - point.yCoordinate
        dz = atom.getZCoordinate() - point.zCoordinate
        return math.sqrt(dx*dx + dy*dy + dz*dz)

    def ClosestAndFurthestAtomToCentroid(self, aMolecule):
        centroid = self.CalculateCentroid(aMolecule)
        distances = []
        for i in range(len(aMolecule.getAtoms())):
            dist = self.EuclideanDistanceMeasure(aMolecule, centroid, i)
            distances.append(AtomIndexAndDistance(i, dist))
        distances.sort(key=lambda x: x.distance)
        return [distances[0], distances[-1]]

    def FurthestAtomFromFurthestAtom(self, aMolecule, furthestAtom):
        index = furthestAtom.index
        target = aMolecule.getAtom(index)
        distances = []
        for i in range(len(aMolecule.getAtoms())):
            atom = aMolecule.getAtom(i)
            dx = atom.getXCoordinate() - target.getXCoordinate()
            dy = atom.getYCoordinate() - target.getYCoordinate()
            dz = atom.getZCoordinate() - target.getZCoordinate()
            dist = math.sqrt(dx*dx + dy*dy + dz*dz)
            distances.append(AtomIndexAndDistance(i, dist))
        distances.sort(key=lambda x: x.distance)
        return distances[-1].index

    def MomentToCentroid(self, momentId, aMolecule, centroid):
        atoms = aMolecule.getAtoms()
        distances = []
        for atom in atoms:
            dx = atom.getXCoordinate() - centroid.xCoordinate
            dy = atom.getYCoordinate() - centroid.yCoordinate
            dz = atom.getZCoordinate() - centroid.zCoordinate
            distances.append(math.sqrt(dx*dx + dy*dy + dz*dz))
        return self._moment(momentId, distances)

    def MomentToX(self, momentId, aMolecule, refIndex):
        ref = aMolecule.getAtom(refIndex)
        distances = []
        for atom in aMolecule.getAtoms():
            dx = atom.getXCoordinate() - ref.getXCoordinate()
            dy = atom.getYCoordinate() - ref.getYCoordinate()
            dz = atom.getZCoordinate() - ref.getZCoordinate()
            distances.append(math.sqrt(dx*dx + dy*dy + dz*dz))
        return self._moment(momentId, distances)

    def _moment(self, momentId, distances):
        n = len(distances)
        mean = sum(distances) / n
        if momentId == 1:
            return mean
        elif momentId == 2:
            return sum((d - mean)**2 for d in distances) / n
        elif momentId == 3:
            variance = sum((d - mean)**2 for d in distances) / n
            skewness = sum(abs(d - mean)**3 for d in distances) / n
            return skewness / (variance ** 1.5) if variance > 0 else 0.0

def getUSRDescriptor(aMolecule):
    usr = USR()
    centroid = usr.CalculateCentroid(aMolecule)
    v = usr.ClosestAndFurthestAtomToCentroid(aMolecule)
    ffaIndex = usr.FurthestAtomFromFurthestAtom(aMolecule, v[1])
    return [
        usr.MomentToCentroid(1, aMolecule, centroid),
        usr.MomentToCentroid(2, aMolecule, centroid),
        usr.MomentToCentroid(3, aMolecule, centroid),
        usr.MomentToX(1, aMolecule, v[0].index),
        usr.MomentToX(2, aMolecule, v[0].index),
        usr.MomentToX(3, aMolecule, v[0].index),
        usr.MomentToX(1, aMolecule, v[1].index),
        usr.MomentToX(2, aMolecule, v[1].index),
        usr.MomentToX(3, aMolecule, v[1].index),
        usr.MomentToX(1, aMolecule, ffaIndex),
        usr.MomentToX(2, aMolecule, ffaIndex),
        usr.MomentToX(3, aMolecule, ffaIndex),
    ]

# %%
import os
import glob
from collections import defaultdict
from tqdm import tqdm

#################################
# AGRUPAMIENTO Y PROCESAMIENTO  #
#################################

# Ruta de la carpeta de entrada con archivos PDB
input_folder = "/content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/ligandos_pdb"

# Ruta de salida para los archivos CSV de USR
output_folder = "/content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR"
os.makedirs(output_folder, exist_ok=True)

# 1. Agrupar por el nombre del ligando, que se encuentra en el índice [1]
ligandos_por_nombre = defaultdict(list)
pdb_files = sorted(glob.glob(os.path.join(input_folder, "*.pdb")))

for filepath in pdb_files:
    base = os.path.basename(filepath)
    parts = base.split("_")
    if len(parts) < 2:
        # Si no se puede dividir correctamente, se ignora
        continue
    ligand_name = parts[1]  # Ejemplo: "GNP"
    ligandos_por_nombre[ligand_name].append(filepath)

# 2. Procesar cada grupo y generar un CSV para cada ligando, omitiendo si ya existe
for ligand_name, archivos in ligandos_por_nombre.items():
    output_path = os.path.join(output_folder, f"USR_{ligand_name}.csv")

    # Si el CSV para este ligando ya existe, se salta el procesamiento
    if os.path.exists(output_path):
        print(f"El archivo {output_path} ya existe. Saltando {ligand_name}.")
        continue

    with open(output_path, 'w') as out:
        out.write("conformation," + ",".join([f"USR_{i+1}" for i in range(12)]) + "\n")
        for pdb_file in tqdm(archivos, desc=f"Procesando {ligand_name}"):
            try:
                mol = readPDBLigand(pdb_file)
                descriptor = getUSRDescriptor(mol)
                desc_line = ",".join([f"{d:.5f}" for d in descriptor])
                out.write(f"{os.path.basename(pdb_file)},{desc_line}\n")
            except Exception as e:
                print(f"Error en {pdb_file}: {e}")
# Out:
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_NBN.csv ya existe. Saltando NBN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GCP.csv ya existe. Saltando GCP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AMP.csv ya existe. Saltando AMP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SAS.csv ya existe. Saltando SAS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_3PG.csv ya existe. Saltando 3PG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GTX.csv ya existe. Saltando GTX.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BNZ.csv ya existe. Saltando BNZ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HED.csv ya existe. Saltando HED.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IND.csv ya existe. Saltando IND.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PXY.csv ya existe. Saltando PXY.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_OXE.csv ya existe. Saltando OXE.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PMP.csv ya existe. Saltando PMP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BEN.csv ya existe. Saltando BEN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FAR.csv ya existe. Saltando FAR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_EST.csv ya existe. Saltando EST.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_STR.csv ya existe. Saltando STR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TFP.csv ya existe. Saltando TFP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GSP.csv ya existe. Saltando GSP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_THP.csv ya existe. Saltando THP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FBP.csv ya existe. Saltando FBP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PGA.csv ya existe. Saltando PGA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ZMR.csv ya existe. Saltando ZMR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GDM.csv ya existe. Saltando GDM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PRH.csv ya existe. Saltando PRH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GDP.csv ya existe. Saltando GDP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GNH.csv ya existe. Saltando GNH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IGP.csv ya existe. Saltando IGP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_OXM.csv ya existe. Saltando OXM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PYE.csv ya existe. Saltando PYE.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FMB.csv ya existe. Saltando FMB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DNN.csv ya existe. Saltando DNN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GLS.csv ya existe. Saltando GLS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GUN.csv ya existe. Saltando GUN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PCP.csv ya existe. Saltando PCP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_XAN.csv ya existe. Saltando XAN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_5GP.csv ya existe. Saltando 5GP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PUT.csv ya existe. Saltando PUT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_U0E.csv ya existe. Saltando U0E.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HPA.csv ya existe. Saltando HPA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_NOS.csv ya existe. Saltando NOS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SB2.csv ya existe. Saltando SB2.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_UPG.csv ya existe. Saltando UPG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MGD.csv ya existe. Saltando MGD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IMP.csv ya existe. Saltando IMP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ARA.csv ya existe. Saltando ARA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ARB.csv ya existe. Saltando ARB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FCA.csv ya existe. Saltando FCA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FCB.csv ya existe. Saltando FCB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_THA.csv ya existe. Saltando THA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PAL.csv ya existe. Saltando PAL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ANP.csv ya existe. Saltando ANP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_1DA.csv ya existe. Saltando 1DA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TAD.csv ya existe. Saltando TAD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ACD.csv ya existe. Saltando ACD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_13P.csv ya existe. Saltando 13P.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HAM.csv ya existe. Saltando HAM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ANL.csv ya existe. Saltando ANL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_4AP.csv ya existe. Saltando 4AP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_NVI.csv ya existe. Saltando NVI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IDM.csv ya existe. Saltando IDM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_2AP.csv ya existe. Saltando 2AP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_1MZ.csv ya existe. Saltando 1MZ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_2MZ.csv ya existe. Saltando 2MZ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AMT.csv ya existe. Saltando AMT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SAH.csv ya existe. Saltando SAH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MBG.csv ya existe. Saltando MBG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_NGA.csv ya existe. Saltando NGA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PAP.csv ya existe. Saltando PAP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ATR.csv ya existe. Saltando ATR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TES.csv ya existe. Saltando TES.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GNP.csv ya existe. Saltando GNP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ADE.csv ya existe. Saltando ADE.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FMP.csv ya existe. Saltando FMP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IOP.csv ya existe. Saltando IOP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HCI.csv ya existe. Saltando HCI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MAE.csv ya existe. Saltando MAE.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ICT.csv ya existe. Saltando ICT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DHY.csv ya existe. Saltando DHY.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MNP.csv ya existe. Saltando MNP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_4HP.csv ya existe. Saltando 4HP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IPH.csv ya existe. Saltando IPH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AKG.csv ya existe. Saltando AKG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BCL.csv ya existe. Saltando BCL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BPH.csv ya existe. Saltando BPH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_LDA.csv ya existe. Saltando LDA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PH2.csv ya existe. Saltando PH2.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SAN.csv ya existe. Saltando SAN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_NOV.csv ya existe. Saltando NOV.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PLA.csv ya existe. Saltando PLA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AP5.csv ya existe. Saltando AP5.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_OAA.csv ya existe. Saltando OAA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ISA.csv ya existe. Saltando ISA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MIC.csv ya existe. Saltando MIC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GUA.csv ya existe. Saltando GUA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CB3.csv ya existe. Saltando CB3.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BE2.csv ya existe. Saltando BE2.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_INS.csv ya existe. Saltando INS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PTE.csv ya existe. Saltando PTE.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_OCT.csv ya existe. Saltando OCT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_STU.csv ya existe. Saltando STU.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_RTL.csv ya existe. Saltando RTL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SFG.csv ya existe. Saltando SFG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TCH.csv ya existe. Saltando TCH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A3P.csv ya existe. Saltando A3P.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PDC.csv ya existe. Saltando PDC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_NPL.csv ya existe. Saltando NPL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PCT.csv ya existe. Saltando PCT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BOG.csv ya existe. Saltando BOG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AGS.csv ya existe. Saltando AGS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AP2.csv ya existe. Saltando AP2.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HSM.csv ya existe. Saltando HSM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IPD.csv ya existe. Saltando IPD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HOP.csv ya existe. Saltando HOP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MTX.csv ya existe. Saltando MTX.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_UMP.csv ya existe. Saltando UMP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AZM.csv ya existe. Saltando AZM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PYJ.csv ya existe. Saltando PYJ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PC.csv ya existe. Saltando PC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TSU.csv ya existe. Saltando TSU.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PLM.csv ya existe. Saltando PLM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CYH.csv ya existe. Saltando CYH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DTT.csv ya existe. Saltando DTT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_XYP.csv ya existe. Saltando XYP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_XYS.csv ya existe. Saltando XYS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_M1A.csv ya existe. Saltando M1A.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GPS.csv ya existe. Saltando GPS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DHB.csv ya existe. Saltando DHB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_4IP.csv ya existe. Saltando 4IP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PGH.csv ya existe. Saltando PGH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DCM.csv ya existe. Saltando DCM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_COD.csv ya existe. Saltando COD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DGN.csv ya existe. Saltando DGN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DG2.csv ya existe. Saltando DG2.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ACO.csv ya existe. Saltando ACO.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IMH.csv ya existe. Saltando IMH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PXG.csv ya existe. Saltando PXG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BLV.csv ya existe. Saltando BLV.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PRL.csv ya existe. Saltando PRL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IN5.csv ya existe. Saltando IN5.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_URA.csv ya existe. Saltando URA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GLC.csv ya existe. Saltando GLC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_NAX.csv ya existe. Saltando NAX.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DUR.csv ya existe. Saltando DUR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PCG.csv ya existe. Saltando PCG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HBD.csv ya existe. Saltando HBD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IPL.csv ya existe. Saltando IPL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PLS.csv ya existe. Saltando PLS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MYR.csv ya existe. Saltando MYR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PHB.csv ya existe. Saltando PHB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DAR.csv ya existe. Saltando DAR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_G6P.csv ya existe. Saltando G6P.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GCO.csv ya existe. Saltando GCO.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_RDC.csv ya existe. Saltando RDC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_UDP.csv ya existe. Saltando UDP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_C8E.csv ya existe. Saltando C8E.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PMB.csv ya existe. Saltando PMB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_35G.csv ya existe. Saltando 35G.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_2GP.csv ya existe. Saltando 2GP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ACV.csv ya existe. Saltando ACV.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_INN.csv ya existe. Saltando INN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FK5.csv ya existe. Saltando FK5.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AP1.csv ya existe. Saltando AP1.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SPD.csv ya existe. Saltando SPD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PC1.csv ya existe. Saltando PC1.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DTP.csv ya existe. Saltando DTP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IHP.csv ya existe. Saltando IHP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BHC.csv ya existe. Saltando BHC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PT1.csv ya existe. Saltando PT1.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_2PE.csv ya existe. Saltando 2PE.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_I3P.csv ya existe. Saltando I3P.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CAA.csv ya existe. Saltando CAA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_XV6.csv ya existe. Saltando XV6.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BLA.csv ya existe. Saltando BLA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PPY.csv ya existe. Saltando PPY.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_146.csv ya existe. Saltando 146.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ATF.csv ya existe. Saltando ATF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_LPC.csv ya existe. Saltando LPC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ADN.csv ya existe. Saltando ADN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ERG.csv ya existe. Saltando ERG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_OES.csv ya existe. Saltando OES.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IMU.csv ya existe. Saltando IMU.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DAL.csv ya existe. Saltando DAL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TCL.csv ya existe. Saltando TCL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BAI.csv ya existe. Saltando BAI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BAB.csv ya existe. Saltando BAB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HFA.csv ya existe. Saltando HFA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MF3.csv ya existe. Saltando MF3.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MPH.csv ya existe. Saltando MPH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GAR.csv ya existe. Saltando GAR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TSN.csv ya existe. Saltando TSN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SHH.csv ya existe. Saltando SHH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_G16.csv ya existe. Saltando G16.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CHI.csv ya existe. Saltando CHI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ESI.csv ya existe. Saltando ESI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PPG.csv ya existe. Saltando PPG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_G3H.csv ya existe. Saltando G3H.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CPB.csv ya existe. Saltando CPB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CFF.csv ya existe. Saltando CFF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_W11.csv ya existe. Saltando W11.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PP3.csv ya existe. Saltando PP3.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_RAP.csv ya existe. Saltando RAP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CP.csv ya existe. Saltando CP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_NVA.csv ya existe. Saltando NVA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ENO.csv ya existe. Saltando ENO.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DPS.csv ya existe. Saltando DPS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TAR.csv ya existe. Saltando TAR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_REA.csv ya existe. Saltando REA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FCO.csv ya existe. Saltando FCO.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DMI.csv ya existe. Saltando DMI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CNC.csv ya existe. Saltando CNC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FOL.csv ya existe. Saltando FOL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DZF.csv ya existe. Saltando DZF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ACA.csv ya existe. Saltando ACA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AMH.csv ya existe. Saltando AMH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CLQ.csv ya existe. Saltando CLQ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HDA.csv ya existe. Saltando HDA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MTA.csv ya existe. Saltando MTA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_NAR.csv ya existe. Saltando NAR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_STL.csv ya existe. Saltando STL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GPX.csv ya existe. Saltando GPX.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HEX.csv ya existe. Saltando HEX.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TAT.csv ya existe. Saltando TAT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DAD.csv ya existe. Saltando DAD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_COT.csv ya existe. Saltando COT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CLM.csv ya existe. Saltando CLM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MLC.csv ya existe. Saltando MLC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PIN.csv ya existe. Saltando PIN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_F6P.csv ya existe. Saltando F6P.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_COH.csv ya existe. Saltando COH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PRE.csv ya existe. Saltando PRE.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AND.csv ya existe. Saltando AND.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CTP.csv ya existe. Saltando CTP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PY6.csv ya existe. Saltando PY6.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_803.csv ya existe. Saltando 803.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_EQU.csv ya existe. Saltando EQU.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TTP.csv ya existe. Saltando TTP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TYD.csv ya existe. Saltando TYD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CMC.csv ya existe. Saltando CMC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_LMR.csv ya existe. Saltando LMR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CMX.csv ya existe. Saltando CMX.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CMP.csv ya existe. Saltando CMP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CBP.csv ya existe. Saltando CBP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TMP.csv ya existe. Saltando TMP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_T3P.csv ya existe. Saltando T3P.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BLG.csv ya existe. Saltando BLG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DMD.csv ya existe. Saltando DMD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_NIO.csv ya existe. Saltando NIO.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PG5.csv ya existe. Saltando PG5.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PG6.csv ya existe. Saltando PG6.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_4NP.csv ya existe. Saltando 4NP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_H4B.csv ya existe. Saltando H4B.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DHT.csv ya existe. Saltando DHT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DDQ.csv ya existe. Saltando DDQ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ORO.csv ya existe. Saltando ORO.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ABH.csv ya existe. Saltando ABH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TPV.csv ya existe. Saltando TPV.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_B3P.csv ya existe. Saltando B3P.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PRP.csv ya existe. Saltando PRP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PEA.csv ya existe. Saltando PEA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AIR.csv ya existe. Saltando AIR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DCS.csv ya existe. Saltando DCS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_LCS.csv ya existe. Saltando LCS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SOR.csv ya existe. Saltando SOR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IKT.csv ya existe. Saltando IKT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DSD.csv ya existe. Saltando DSD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ACP.csv ya existe. Saltando ACP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DTB.csv ya existe. Saltando DTB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_VDX.csv ya existe. Saltando VDX.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_RIP.csv ya existe. Saltando RIP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_U5P.csv ya existe. Saltando U5P.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AS1.csv ya existe. Saltando AS1.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HBI.csv ya existe. Saltando HBI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_RNS.csv ya existe. Saltando RNS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PYZ.csv ya existe. Saltando PYZ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DGP.csv ya existe. Saltando DGP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FFO.csv ya existe. Saltando FFO.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PLG.csv ya existe. Saltando PLG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SLB.csv ya existe. Saltando SLB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TOP.csv ya existe. Saltando TOP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FOF.csv ya existe. Saltando FOF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FOH.csv ya existe. Saltando FOH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_NOJ.csv ya existe. Saltando NOJ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_EQP.csv ya existe. Saltando EQP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PCR.csv ya existe. Saltando PCR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GLA.csv ya existe. Saltando GLA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IP2.csv ya existe. Saltando IP2.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BMS.csv ya existe. Saltando BMS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_OLA.csv ya existe. Saltando OLA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HAI.csv ya existe. Saltando HAI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_UDX.csv ya existe. Saltando UDX.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_UGA.csv ya existe. Saltando UGA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CAQ.csv ya existe. Saltando CAQ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HMD.csv ya existe. Saltando HMD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HRG.csv ya existe. Saltando HRG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_NCA.csv ya existe. Saltando NCA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MCT.csv ya existe. Saltando MCT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DMQ.csv ya existe. Saltando DMQ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PGD.csv ya existe. Saltando PGD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_RDF.csv ya existe. Saltando RDF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MHF.csv ya existe. Saltando MHF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DOB.csv ya existe. Saltando DOB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HMG.csv ya existe. Saltando HMG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_6PG.csv ya existe. Saltando 6PG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AAG.csv ya existe. Saltando AAG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BEP.csv ya existe. Saltando BEP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_4MZ.csv ya existe. Saltando 4MZ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_APG.csv ya existe. Saltando APG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FTC.csv ya existe. Saltando FTC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DUD.csv ya existe. Saltando DUD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HAR.csv ya existe. Saltando HAR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DQN.csv ya existe. Saltando DQN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BCB.csv ya existe. Saltando BCB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BPB.csv ya existe. Saltando BPB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_NS5.csv ya existe. Saltando NS5.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_COI.csv ya existe. Saltando COI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SNP.csv ya existe. Saltando SNP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DDF.csv ya existe. Saltando DDF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CAM.csv ya existe. Saltando CAM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SES.csv ya existe. Saltando SES.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PRZ.csv ya existe. Saltando PRZ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BZM.csv ya existe. Saltando BZM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BZQ.csv ya existe. Saltando BZQ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_UNA.csv ya existe. Saltando UNA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IPB.csv ya existe. Saltando IPB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_1PG.csv ya existe. Saltando 1PG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FCR.csv ya existe. Saltando FCR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SPN.csv ya existe. Saltando SPN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DCA.csv ya existe. Saltando DCA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CMG.csv ya existe. Saltando CMG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_THM.csv ya existe. Saltando THM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TMC.csv ya existe. Saltando TMC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_3EP.csv ya existe. Saltando 3EP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_R18.csv ya existe. Saltando R18.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CXF.csv ya existe. Saltando CXF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DXC.csv ya existe. Saltando DXC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AAE.csv ya existe. Saltando AAE.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DTD.csv ya existe. Saltando DTD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TBP.csv ya existe. Saltando TBP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_UVW.csv ya existe. Saltando UVW.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_COM.csv ya existe. Saltando COM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_F43.csv ya existe. Saltando F43.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TP7.csv ya existe. Saltando TP7.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BG6.csv ya existe. Saltando BG6.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PFL.csv ya existe. Saltando PFL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HLT.csv ya existe. Saltando HLT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DKA.csv ya existe. Saltando DKA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DAO.csv ya existe. Saltando DAO.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_STE.csv ya existe. Saltando STE.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_LY2.csv ya existe. Saltando LY2.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_API.csv ya existe. Saltando API.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_QUE.csv ya existe. Saltando QUE.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MYC.csv ya existe. Saltando MYC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ATM.csv ya existe. Saltando ATM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_INR.csv ya existe. Saltando INR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GCS.csv ya existe. Saltando GCS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PIM.csv ya existe. Saltando PIM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A70.csv ya existe. Saltando A70.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HBA.csv ya existe. Saltando HBA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PAH.csv ya existe. Saltando PAH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HSE.csv ya existe. Saltando HSE.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_XYH.csv ya existe. Saltando XYH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TSA.csv ya existe. Saltando TSA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ILO.csv ya existe. Saltando ILO.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DND.csv ya existe. Saltando DND.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CHD.csv ya existe. Saltando CHD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_UMA.csv ya existe. Saltando UMA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GAA.csv ya existe. Saltando GAA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_2CP.csv ya existe. Saltando 2CP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MAK.csv ya existe. Saltando MAK.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TTN.csv ya existe. Saltando TTN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PRF.csv ya existe. Saltando PRF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CO8.csv ya existe. Saltando CO8.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IC1.csv ya existe. Saltando IC1.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BNG.csv ya existe. Saltando BNG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HAS.csv ya existe. Saltando HAS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PPF.csv ya existe. Saltando PPF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PLC.csv ya existe. Saltando PLC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_M7G.csv ya existe. Saltando M7G.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CZH.csv ya existe. Saltando CZH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DMG.csv ya existe. Saltando DMG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PYC.csv ya existe. Saltando PYC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CSS.csv ya existe. Saltando CSS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PDA.csv ya existe. Saltando PDA.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_4NC.csv ya existe. Saltando 4NC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_9CR.csv ya existe. Saltando 9CR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ADQ.csv ya existe. Saltando ADQ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MG7.csv ya existe. Saltando MG7.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CTS.csv ya existe. Saltando CTS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HEV.csv ya existe. Saltando HEV.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IBP.csv ya existe. Saltando IBP.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_2PG.csv ya existe. Saltando 2PG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_RAL.csv ya existe. Saltando RAL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_LAR.csv ya existe. Saltando LAR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_T44.csv ya existe. Saltando T44.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GAS.csv ya existe. Saltando GAS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ASD.csv ya existe. Saltando ASD.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DAN.csv ya existe. Saltando DAN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CRS.csv ya existe. Saltando CRS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_RCO.csv ya existe. Saltando RCO.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MYS.csv ya existe. Saltando MYS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PAE.csv ya existe. Saltando PAE.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BLM.csv ya existe. Saltando BLM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CPS.csv ya existe. Saltando CPS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_LMU.csv ya existe. Saltando LMU.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DUT.csv ya existe. Saltando DUT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PMM.csv ya existe. Saltando PMM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_2AN.csv ya existe. Saltando 2AN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PEL.csv ya existe. Saltando PEL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MPO.csv ya existe. Saltando MPO.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SMA.csv ya existe. Saltando SMA.
# ...
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_T0O.csv ya existe. Saltando T0O.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_WFI.csv ya existe. Saltando WFI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_UJQ.csv ya existe. Saltando UJQ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_9OI.csv ya existe. Saltando 9OI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1AJ5.csv ya existe. Saltando A1AJ5.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1AKB.csv ya existe. Saltando A1AKB.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1AMX.csv ya existe. Saltando A1AMX.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1AMZ.csv ya existe. Saltando A1AMZ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1AM1.csv ya existe. Saltando A1AM1.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_X0S.csv ya existe. Saltando X0S.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ZUG.csv ya existe. Saltando ZUG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_K24.csv ya existe. Saltando K24.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1AM6.csv ya existe. Saltando A1AM6.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1AM7.csv ya existe. Saltando A1AM7.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_K2S.csv ya existe. Saltando K2S.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_V3U.csv ya existe. Saltando V3U.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1AP3.csv ya existe. Saltando A1AP3.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_XJJ.csv ya existe. Saltando XJJ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IRU.csv ya existe. Saltando IRU.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1H97.csv ya existe. Saltando A1H97.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TU6.csv ya existe. Saltando TU6.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1A3S.csv ya existe. Saltando A1A3S.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1A4A.csv ya existe. Saltando A1A4A.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1A3W.csv ya existe. Saltando A1A3W.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1A36.csv ya existe. Saltando A1A36.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1H9V.csv ya existe. Saltando A1H9V.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1H9U.csv ya existe. Saltando A1H9U.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1BDJ.csv ya existe. Saltando A1BDJ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_Q4L.csv ya existe. Saltando Q4L.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_K3J.csv ya existe. Saltando K3J.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_UIS.csv ya existe. Saltando UIS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_T9S.csv ya existe. Saltando T9S.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AWU.csv ya existe. Saltando AWU.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_WBV.csv ya existe. Saltando WBV.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PKZ.csv ya existe. Saltando PKZ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_X4V.csv ya existe. Saltando X4V.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_XB7.csv ya existe. Saltando XB7.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_XY4.csv ya existe. Saltando XY4.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_G4C.csv ya existe. Saltando G4C.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_UB7.csv ya existe. Saltando UB7.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BQ1.csv ya existe. Saltando BQ1.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_JH1.csv ya existe. Saltando JH1.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_AV0.csv ya existe. Saltando AV0.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_VCW.csv ya existe. Saltando VCW.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_0IM.csv ya existe. Saltando 0IM.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_QVR.csv ya existe. Saltando QVR.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_0NI.csv ya existe. Saltando 0NI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_CD4.csv ya existe. Saltando CD4.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_4R7.csv ya existe. Saltando 4R7.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_5IV.csv ya existe. Saltando 5IV.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_5IK.csv ya existe. Saltando 5IK.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_9D2.csv ya existe. Saltando 9D2.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_7RI.csv ya existe. Saltando 7RI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_80M.csv ya existe. Saltando 80M.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_1TF.csv ya existe. Saltando 1TF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_8L6.csv ya existe. Saltando 8L6.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_JO4.csv ya existe. Saltando JO4.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_N6M.csv ya existe. Saltando N6M.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_8QY.csv ya existe. Saltando 8QY.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_MW9.csv ya existe. Saltando MW9.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_I7Y.csv ya existe. Saltando I7Y.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IXO.csv ya existe. Saltando IXO.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_KT0.csv ya existe. Saltando KT0.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_P42.csv ya existe. Saltando P42.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_KXX.csv ya existe. Saltando KXX.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_TB1.csv ya existe. Saltando TB1.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GGL.csv ya existe. Saltando GGL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_O6O.csv ya existe. Saltando O6O.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_WHL.csv ya existe. Saltando WHL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_OJC.csv ya existe. Saltando OJC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FJF.csv ya existe. Saltando FJF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_7YY.csv ya existe. Saltando 7YY.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SQL.csv ya existe. Saltando SQL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_7OW.csv ya existe. Saltando 7OW.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_JHL.csv ya existe. Saltando JHL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_BGI.csv ya existe. Saltando BGI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_D21.csv ya existe. Saltando D21.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_IO9.csv ya existe. Saltando IO9.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_OX8.csv ya existe. Saltando OX8.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_9QN.csv ya existe. Saltando 9QN.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_Q7G.csv ya existe. Saltando Q7G.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_QGL.csv ya existe. Saltando QGL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SIT.csv ya existe. Saltando SIT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_U30.csv ya existe. Saltando U30.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_U8O.csv ya existe. Saltando U8O.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_SY4.csv ya existe. Saltando SY4.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_R8S.csv ya existe. Saltando R8S.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_R8V.csv ya existe. Saltando R8V.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_UHL.csv ya existe. Saltando UHL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_RAY.csv ya existe. Saltando RAY.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_RB7.csv ya existe. Saltando RB7.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_UI4.csv ya existe. Saltando UI4.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_REG.csv ya existe. Saltando REG.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_DU0.csv ya existe. Saltando DU0.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_Q3V.csv ya existe. Saltando Q3V.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_QBC.csv ya existe. Saltando QBC.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_QF6.csv ya existe. Saltando QF6.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_T83.csv ya existe. Saltando T83.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_VWX.csv ya existe. Saltando VWX.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_PEX.csv ya existe. Saltando PEX.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_Y72.csv ya existe. Saltando Y72.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_Y79.csv ya existe. Saltando Y79.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_Y6U.csv ya existe. Saltando Y6U.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GTF.csv ya existe. Saltando GTF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_YUT.csv ya existe. Saltando YUT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_KHF.csv ya existe. Saltando KHF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_VIS.csv ya existe. Saltando VIS.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_XUH.csv ya existe. Saltando XUH.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ITF.csv ya existe. Saltando ITF.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_KDL.csv ya existe. Saltando KDL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_P5O.csv ya existe. Saltando P5O.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_OKL.csv ya existe. Saltando OKL.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_FI7.csv ya existe. Saltando FI7.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_C0N.csv ya existe. Saltando C0N.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_67I.csv ya existe. Saltando 67I.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_64X.csv ya existe. Saltando 64X.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_JL3.csv ya existe. Saltando JL3.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_VZ6.csv ya existe. Saltando VZ6.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_XP6.csv ya existe. Saltando XP6.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_HCZ.csv ya existe. Saltando HCZ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ZP2.csv ya existe. Saltando ZP2.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_YNK.csv ya existe. Saltando YNK.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_GOQ.csv ya existe. Saltando GOQ.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_JQ9.csv ya existe. Saltando JQ9.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_RTO.csv ya existe. Saltando RTO.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ZWY.csv ya existe. Saltando ZWY.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_ZNI.csv ya existe. Saltando ZNI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1AEI.csv ya existe. Saltando A1AEI.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_B40.csv ya existe. Saltando B40.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1ANT.csv ya existe. Saltando A1ANT.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1A1O.csv ya existe. Saltando A1A1O.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1A1P.csv ya existe. Saltando A1A1P.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_A1H9O.csv ya existe. Saltando A1H9O.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_VDW.csv ya existe. Saltando VDW.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_1JW.csv ya existe. Saltando 1JW.
# El archivo /content/drive/MyDrive/TFM/T2/Ultrafast_Shape_Recognition/Output_USR/USR_YZT.csv ya existe. Saltando YZT.
